# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db605661e640a8018d0d6142a71f9215 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db605661e640a8018d0d6142a71f9215&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db605661e640a8018d0d6142a71f9215 = L.map(
#                 &quot;map_db605661e640a8018d0d6142a71f9215&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e531e06d13eb50b02e90e306ad24e88 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e531e06d13eb50b02e90e306ad24e88.addTo(map_db605661e640a8018d0d6142a71f9215);
#
#
#             var marker_a33432ae8943863fde2b4d33fea2cc3e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_db605661e640a8018d0d6142a71f9215);
#
#
#         var popup_4a16d8b6666966ae53d3afbcc2d14029 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_056bf0c50cf8404c26760c510983bc90 = $(`&lt;div id=&quot;html_056bf0c50cf8404c26760c510983bc90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4a16d8b6666966ae53d3afbcc2d14029.setContent(html_056bf0c50cf8404c26760c510983bc90);
#
#
#
#         marker_a33432ae8943863fde2b4d33fea2cc3e.bindPopup(popup_4a16d8b6666966ae53d3afbcc2d14029)
#         ;
#
#
#
#
#             var marker_2b97d8d1e8387b5abb1bdcb0149e462a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_db605661e640a8018d0d6142a71f9215);
#
#
#         var popup_94425e6d72580cc6fbf2af5e0a6d107a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b196a442f0f8aef65918dd7f6e5d6f7 = $(`&lt;div id=&quot;html_5b196a442f0f8aef65918dd7f6e5d6f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_94425e6d72580cc6fbf2af5e0a6d107a.setContent(html_5b196a442f0f8aef65918dd7f6e5d6f7);
#
#
#
#         marker_2b97d8d1e8387b5abb1bdcb0149e462a.bindPopup(popup_94425e6d72580cc6fbf2af5e0a6d107a)
#         ;
#
#
#
#
#             var marker_8674da36fa6d542437e51157fc37371e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_db605661e640a8018d0d6142a71f9215);
#
#
#         var popup_29d01cbefe2702e968c0b93053e834e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62c11fce7655571cd9a77a7bdc0a743a = $(`&lt;div id=&quot;html_62c11fce7655571cd9a77a7bdc0a743a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_29d01cbefe2702e968c0b93053e834e6.setContent(html_62c11fce7655571cd9a77a7bdc0a743a);
#
#
#
#         marker_8674da36fa6d542437e51157fc37371e.bindPopup(popup_29d01cbefe2702e968c0b93053e834e6)
#         ;
#
#
#
#
#             var marker_880e60ddd4b5eb9b193a75dfda313ffa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_db605661e640a8018d0d6142a71f9215);
#
#
#         var popup_fe264452d7610b7debf0ade17fa5eb6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_205aff453c18e79dbabf899b3e9309f8 = $(`&lt;div id=&quot;html_205aff453c18e79dbabf899b3e9309f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fe264452d7610b7debf0ade17fa5eb6c.setContent(html_205aff453c18e79dbabf899b3e9309f8);
#
#
#
#         marker_880e60ddd4b5eb9b193a75dfda313ffa.bindPopup(popup_fe264452d7610b7debf0ade17fa5eb6c)
#         ;
#
#
#
#
#             var marker_bccde23c1377a0e55843631ecc778d31 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_db605661e640a8018d0d6142a71f9215);
#
#
#         var popup_92c7daf32fe346ebe32aa7b4f92e0a9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e00988e980d06dfc376ab12b2e7464b0 = $(`&lt;div id=&quot;html_e00988e980d06dfc376ab12b2e7464b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_92c7daf32fe346ebe32aa7b4f92e0a9e.setContent(html_e00988e980d06dfc376ab12b2e7464b0);
#
#
#
#         marker_bccde23c1377a0e55843631ecc778d31.bindPopup(popup_92c7daf32fe346ebe32aa7b4f92e0a9e)
#         ;
#
#
#
#
#             var marker_350ba0ee63

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81c606717703fe0275d416c048124716 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81c606717703fe0275d416c048124716&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81c606717703fe0275d416c048124716 = L.map(
#                 &quot;map_81c606717703fe0275d416c048124716&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6c3dfeb10e7d59172593772fe965780 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d6c3dfeb10e7d59172593772fe965780.addTo(map_81c606717703fe0275d416c048124716);
#
#
#             var feature_group_ff13fdb991372532ea9015c6d0a0234c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a03d3be520e09e8c6f8341fb5414a349 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ff13fdb991372532ea9015c6d0a0234c);
#
#
#         var popup_831053ddf59daa3d7b0e712deae91550 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df74213f4177c6c34ac253f7ee9c2eec = $(`&lt;div id=&quot;html_df74213f4177c6c34ac253f7ee9c2eec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_831053ddf59daa3d7b0e712deae91550.setContent(html_df74213f4177c6c34ac253f7ee9c2eec);
#
#
#
#         marker_a03d3be520e09e8c6f8341fb5414a349.bindPopup(popup_831053ddf59daa3d7b0e712deae91550)
#         ;
#
#
#
#
#             var marker_994493651777600af25b8107fe8485b9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ff13fdb991372532ea9015c6d0a0234c);
#
#
#         var popup_63bd4c92fbebaf5ab30b00b0131873f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54775e0d0f3671ac91cfc1dc695bbe67 = $(`&lt;div id=&quot;html_54775e0d0f3671ac91cfc1dc695bbe67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_63bd4c92fbebaf5ab30b00b0131873f3.setContent(html_54775e0d0f3671ac91cfc1dc695bbe67);
#
#
#
#         marker_994493651777600af25b8107fe8485b9.bindPopup(popup_63bd4c92fbebaf5ab30b00b0131873f3)
#         ;
#
#
#
#
#             var marker_864927b5296465b65a4ae5b52799c7a3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ff13fdb991372532ea9015c6d0a0234c);
#
#
#         var popup_bd185cf9335c2af7b9a8da80a4377a20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a3cb63ad7a4603a3e339e777163827b = $(`&lt;div id=&quot;html_2a3cb63ad7a4603a3e339e777163827b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bd185cf9335c2af7b9a8da80a4377a20.setContent(html_2a3cb63ad7a4603a3e339e777163827b);
#
#
#
#         marker_864927b5296465b65a4ae5b52799c7a3.bindPopup(popup_bd185cf9335c2af7b9a8da80a4377a20)
#         ;
#
#
#
#
#             var marker_3f12f2c69f5ff042dd872cbeef64fad4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ff13fdb991372532ea9015c6d0a0234c);
#
#
#         var popup_73cb5f6340f50f8af406df728d490a3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_529f69b2953624daf901f70612e71abb = $(`&lt;div id=&quot;html_529f69b2953624daf901f70612e71abb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_73cb5f6340f50f8af406df728d490a3a.setContent(html_529f69b2953624daf901f70612e71abb);
#
#
#
#         marker_3f12f2c69f5ff042dd872cbeef64fad4.bindPopup(popup_73cb5f6340f50f8af406df728d490a3a)
#         ;
#
#
#
#
#             var marker_b501185a53f8a4506a7848ed4e36712d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ff13fdb991372532ea9015c6d0a0234c);
#
#
#         var popup_b61104fd04863a6621ce561414136c7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c777857f2a66f272bbd653fd9ee614e = $(`&lt;div id=&quot;html_5c777857f2a66f272bbd653fd9ee614e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_b61104fd04863a6621

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0e28328b813b4b744a78eccfffcaab8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0e28328b813b4b744a78eccfffcaab8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0e28328b813b4b744a78eccfffcaab8 = L.map(
#                 &quot;map_c0e28328b813b4b744a78eccfffcaab8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b65d074e2a771270f8fe7ec67084ce3e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b65d074e2a771270f8fe7ec67084ce3e.addTo(map_c0e28328b813b4b744a78eccfffcaab8);
#
#
#             var feature_group_98a0c6c2b4cb7fa56f9c87cabfa4c7b3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_98a0c6c2b4cb7fa56f9c87cabfa4c7b3.addTo(map_c0e28328b813b4b744a78eccfffcaab8);
#
#
#             var feature_group_sub_group_13f5130b3f8cd4b899a7de6c098de4b5 = L.featureGroup.subGroup(
#                 feature_group_98a0c6c2b4cb7fa56f9c87cabfa4c7b3
#             );
#
#
#             var marker_a1bdaee2d64657809abf2278289a1ef0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_13f5130b3f8cd4b899a7de6c098de4b5);
#
#
#         var popup_eb884ba88c496acc38312ad05d51a1c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d7b7c463a6a3bb6230de85b391430f4 = $(`&lt;div id=&quot;html_9d7b7c463a6a3bb6230de85b391430f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_eb884ba88c496acc38312ad05d51a1c1.setContent(html_9d7b7c463a6a3bb6230de85b391430f4);
#
#
#
#         marker_a1bdaee2d64657809abf2278289a1ef0.bindPopup(popup_eb884ba88c496acc38312ad05d51a1c1)
#         ;
#
#
#
#
#             var marker_d61e053a8cd89a6e3d3858c1e3cf3054 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_13f5130b3f8cd4b899a7de6c098de4b5);
#
#
#         var popup_4368dea06810deae951f1c12534f8e7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1f6511d2ef07dc121730e3235144059 = $(`&lt;div id=&quot;html_d1f6511d2ef07dc121730e3235144059&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4368dea06810deae951f1c12534f8e7b.setContent(html_d1f6511d2ef07dc121730e3235144059);
#
#
#
#         marker_d61e053a8cd89a6e3d3858c1e3cf3054.bindPopup(popup_4368dea06810deae951f1c12534f8e7b)
#         ;
#
#
#
#
#             var marker_0dba8c834173c1cd9dcbfa796bbe0f35 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_13f5130b3f8cd4b899a7de6c098de4b5);
#
#
#         var popup_406bb5c5580c2bb1170a75f7292bbb3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcae9e926ed79c2b60acb4670b263025 = $(`&lt;div id=&quot;html_fcae9e926ed79c2b60acb4670b263025&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_406bb5c5580c2bb1170a75f7292bbb3c.setContent(html_fcae9e926ed79c2b60acb4670b263025);
#
#
#
#         marker_0dba8c834173c1cd9dcbfa796bbe0f35.bindPopup(popup_406bb5c5580c2bb1170a75f7292bbb3c)
#         ;
#
#
#
#
#             var marker_20ccdc58782ceb9c740c389d9db2de5f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_13f5130b3f8cd4b899a7de6c098de4b5);
#
#
#         var popup_ab415e16b22ba2fc71bbfbf4a0d42bf0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68950f150e418e712eb54061b5eecf88 = $(`&lt;div id=&quot;html_68950f150e418e712eb54061b5eecf88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ab415e16b22ba2fc71bbfbf4a0d42bf0.setContent(html_68950f150e418e712eb54061b5eecf88);
#
#
#
#         marker_20ccdc58782ceb9c740c389d9db2de5f.bindPopup(popup_ab415e16b22ba2fc71bbfbf4a0d42bf0)
#         ;
#
#
#
#
#             var marker_7068bf20cb6544f7f511770cd5ff252b = L.marker(
#                 [45.050399999999996, 3.0504],
