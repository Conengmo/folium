# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0eb9e7f54e01816899a23170b864799a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0eb9e7f54e01816899a23170b864799a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0eb9e7f54e01816899a23170b864799a = L.map(
#                 &quot;map_0eb9e7f54e01816899a23170b864799a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66ee0efb6125c01be95427ec32c1829f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_66ee0efb6125c01be95427ec32c1829f.addTo(map_0eb9e7f54e01816899a23170b864799a);
#
#
#             var marker_a609367c0d5572178a4387c38f1323f4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0eb9e7f54e01816899a23170b864799a);
#
#
#         var popup_b5a220b79b2ed6a2d180570ade2d2e98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c53c018a1dd5f329c51a2f778fbdd48 = $(`&lt;div id=&quot;html_1c53c018a1dd5f329c51a2f778fbdd48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b5a220b79b2ed6a2d180570ade2d2e98.setContent(html_1c53c018a1dd5f329c51a2f778fbdd48);
#
#
#
#         marker_a609367c0d5572178a4387c38f1323f4.bindPopup(popup_b5a220b79b2ed6a2d180570ade2d2e98)
#         ;
#
#
#
#
#             var marker_9ccff7b4f4d44e655c7af83c69225ae0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0eb9e7f54e01816899a23170b864799a);
#
#
#         var popup_9fea530af17209f33e7ae112d80866b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bef6d71d5ae3f9f936fc75085facf2c3 = $(`&lt;div id=&quot;html_bef6d71d5ae3f9f936fc75085facf2c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9fea530af17209f33e7ae112d80866b9.setContent(html_bef6d71d5ae3f9f936fc75085facf2c3);
#
#
#
#         marker_9ccff7b4f4d44e655c7af83c69225ae0.bindPopup(popup_9fea530af17209f33e7ae112d80866b9)
#         ;
#
#
#
#
#             var marker_099ee7c66028a95f3b9b814b832382b8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0eb9e7f54e01816899a23170b864799a);
#
#
#         var popup_33192e971f61bd49ea5d11ff246737af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41322d2e81bac050c70ca310a528cb46 = $(`&lt;div id=&quot;html_41322d2e81bac050c70ca310a528cb46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_33192e971f61bd49ea5d11ff246737af.setContent(html_41322d2e81bac050c70ca310a528cb46);
#
#
#
#         marker_099ee7c66028a95f3b9b814b832382b8.bindPopup(popup_33192e971f61bd49ea5d11ff246737af)
#         ;
#
#
#
#
#             var marker_917d92aa2ae3d6cdb512f592deedaded = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0eb9e7f54e01816899a23170b864799a);
#
#
#         var popup_2a4f02d4de9918a4f2fbe01b2c3c5140 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2688cfed3b490e873391ea38ad09c945 = $(`&lt;div id=&quot;html_2688cfed3b490e873391ea38ad09c945&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2a4f02d4de9918a4f2fbe01b2c3c5140.setContent(html_2688cfed3b490e873391ea38ad09c945);
#
#
#
#         marker_917d92aa2ae3d6cdb512f592deedaded.bindPopup(popup_2a4f02d4de9918a4f2fbe01b2c3c5140)
#         ;
#
#
#
#
#             var marker_99a0e04c9e4ed644b1127a75743577ec = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0eb9e7f54e01816899a23170b864799a);
#
#
#         var popup_dc8efbe948d42bbe3502434d5c21b84f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e986ab461f15662e04cf6ebb6c27b6b6 = $(`&lt;div id=&quot;html_e986ab461f15662e04cf6ebb6c27b6b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_dc8efbe948d42bbe3502434d5c21b84f.setContent(html_e986ab461f15662e04cf6ebb6c27b6b6);
#
#
#
#         marker_99a0e04c9e4ed644b1127a75743577ec.bindPopup(popup_dc8efbe948d42bbe3502434d5c21b84f)
#         ;
#
#
#
#
#             var marker_3b661c01d5

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b30930c773abd6c8a593ed0521eb6291 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b30930c773abd6c8a593ed0521eb6291&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b30930c773abd6c8a593ed0521eb6291 = L.map(
#                 &quot;map_b30930c773abd6c8a593ed0521eb6291&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_118c9fa12368e9b62f0398f1b823165b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_118c9fa12368e9b62f0398f1b823165b.addTo(map_b30930c773abd6c8a593ed0521eb6291);
#
#
#             var feature_group_9729cec8a30ecb793ad5eaaee7be4027 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_64cc8099ab272f89adf1942bd6863855 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9729cec8a30ecb793ad5eaaee7be4027);
#
#
#         var popup_0f2ade17363115eeb2b2078c4564b251 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1964c3df39a5671d03ae1644656e3432 = $(`&lt;div id=&quot;html_1964c3df39a5671d03ae1644656e3432&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0f2ade17363115eeb2b2078c4564b251.setContent(html_1964c3df39a5671d03ae1644656e3432);
#
#
#
#         marker_64cc8099ab272f89adf1942bd6863855.bindPopup(popup_0f2ade17363115eeb2b2078c4564b251)
#         ;
#
#
#
#
#             var marker_b70c577b4a6f502ad80d04639a38b97c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9729cec8a30ecb793ad5eaaee7be4027);
#
#
#         var popup_52dbedd82a17105cbf940ff172226823 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5319bbceb0c59b3bc872c062646039b2 = $(`&lt;div id=&quot;html_5319bbceb0c59b3bc872c062646039b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_52dbedd82a17105cbf940ff172226823.setContent(html_5319bbceb0c59b3bc872c062646039b2);
#
#
#
#         marker_b70c577b4a6f502ad80d04639a38b97c.bindPopup(popup_52dbedd82a17105cbf940ff172226823)
#         ;
#
#
#
#
#             var marker_cabb6a7ed8ad769f9d497ff0fb70c800 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9729cec8a30ecb793ad5eaaee7be4027);
#
#
#         var popup_e9755bb96053480bec6628772bb5a3bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f71bee0265074da52462e817d33f4c7 = $(`&lt;div id=&quot;html_4f71bee0265074da52462e817d33f4c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e9755bb96053480bec6628772bb5a3bd.setContent(html_4f71bee0265074da52462e817d33f4c7);
#
#
#
#         marker_cabb6a7ed8ad769f9d497ff0fb70c800.bindPopup(popup_e9755bb96053480bec6628772bb5a3bd)
#         ;
#
#
#
#
#             var marker_c1b876e51c103c7d52ffbc5b203493a5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9729cec8a30ecb793ad5eaaee7be4027);
#
#
#         var popup_0369104df96fc1187fab611e11eb6f5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c84ee8dfb5c8cbb871e423be32571e96 = $(`&lt;div id=&quot;html_c84ee8dfb5c8cbb871e423be32571e96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0369104df96fc1187fab611e11eb6f5a.setContent(html_c84ee8dfb5c8cbb871e423be32571e96);
#
#
#
#         marker_c1b876e51c103c7d52ffbc5b203493a5.bindPopup(popup_0369104df96fc1187fab611e11eb6f5a)
#         ;
#
#
#
#
#             var marker_9dbbca175f7f4a75120cf8439561f4af = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9729cec8a30ecb793ad5eaaee7be4027);
#
#
#         var popup_a84114b23e8b2eb41e6fd869b87f8e51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a6d7d8b4e176e8ac8008a1819f39057 = $(`&lt;div id=&quot;html_1a6d7d8b4e176e8ac8008a1819f39057&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_a84114b23e8b2eb41e

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e5cfc95eeaf39acf34c6fdc71140e99 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e5cfc95eeaf39acf34c6fdc71140e99&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e5cfc95eeaf39acf34c6fdc71140e99 = L.map(
#                 &quot;map_5e5cfc95eeaf39acf34c6fdc71140e99&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4691f4f56aab9d856dad2bd8baf029ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4691f4f56aab9d856dad2bd8baf029ae.addTo(map_5e5cfc95eeaf39acf34c6fdc71140e99);
#
#
#             var feature_group_36c91a048bac194870a7ad59b2bd82eb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_36c91a048bac194870a7ad59b2bd82eb.addTo(map_5e5cfc95eeaf39acf34c6fdc71140e99);
#
#
#             var feature_group_sub_group_62cc0b77a16b434d5732f0c71b05daff = L.featureGroup.subGroup(
#                 feature_group_36c91a048bac194870a7ad59b2bd82eb
#             );
#
#
#             var marker_de9a9162998577429e3b8cb172655e58 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_62cc0b77a16b434d5732f0c71b05daff);
#
#
#         var popup_7e51c162b64d9d42c6d2b7ccade35d23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_372a023e39fc6db3904029e02b5e8bf5 = $(`&lt;div id=&quot;html_372a023e39fc6db3904029e02b5e8bf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7e51c162b64d9d42c6d2b7ccade35d23.setContent(html_372a023e39fc6db3904029e02b5e8bf5);
#
#
#
#         marker_de9a9162998577429e3b8cb172655e58.bindPopup(popup_7e51c162b64d9d42c6d2b7ccade35d23)
#         ;
#
#
#
#
#             var marker_334e9cc67adde5792e2037e8a422b09b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_62cc0b77a16b434d5732f0c71b05daff);
#
#
#         var popup_c2b621b29a10b89d8873faaf337ad11f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f09f29be61aec86bf2c1911dc4a7f93 = $(`&lt;div id=&quot;html_7f09f29be61aec86bf2c1911dc4a7f93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c2b621b29a10b89d8873faaf337ad11f.setContent(html_7f09f29be61aec86bf2c1911dc4a7f93);
#
#
#
#         marker_334e9cc67adde5792e2037e8a422b09b.bindPopup(popup_c2b621b29a10b89d8873faaf337ad11f)
#         ;
#
#
#
#
#             var marker_809e900e4b86dc686640bf86cf92a1f1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_62cc0b77a16b434d5732f0c71b05daff);
#
#
#         var popup_c3b66d58ebcb62c8fc4c52a06d4a266c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b1b7ea71ef21b4fbff8b4d943493287 = $(`&lt;div id=&quot;html_5b1b7ea71ef21b4fbff8b4d943493287&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c3b66d58ebcb62c8fc4c52a06d4a266c.setContent(html_5b1b7ea71ef21b4fbff8b4d943493287);
#
#
#
#         marker_809e900e4b86dc686640bf86cf92a1f1.bindPopup(popup_c3b66d58ebcb62c8fc4c52a06d4a266c)
#         ;
#
#
#
#
#             var marker_ef17aceb7bcf183199c2ca498307bdfd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_62cc0b77a16b434d5732f0c71b05daff);
#
#
#         var popup_c4b212ffa70933b83bc476127a713501 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4a3569401648396f5b8782a8b443c6b = $(`&lt;div id=&quot;html_f4a3569401648396f5b8782a8b443c6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c4b212ffa70933b83bc476127a713501.setContent(html_f4a3569401648396f5b8782a8b443c6b);
#
#
#
#         marker_ef17aceb7bcf183199c2ca498307bdfd.bindPopup(popup_c4b212ffa70933b83bc476127a713501)
#         ;
#
#
#
#
#             var marker_d96482cd4e12cdae0707248c7fa74aa9 = L.marker(
#                 [45.050399999999996, 3.0504],
