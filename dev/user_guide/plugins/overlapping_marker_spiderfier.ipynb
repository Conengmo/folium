# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60e5b75535866f8af154717bfaf9e751 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60e5b75535866f8af154717bfaf9e751&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60e5b75535866f8af154717bfaf9e751 = L.map(
#                 &quot;map_60e5b75535866f8af154717bfaf9e751&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56f8b4a93b27329b0915e603c70d22a7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_56f8b4a93b27329b0915e603c70d22a7.addTo(map_60e5b75535866f8af154717bfaf9e751);
#
#
#             var marker_bae23d1e6173ffffb02a2b4799604b4d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_60e5b75535866f8af154717bfaf9e751);
#
#
#         var popup_908e0ec9abad35013b7d49def8156925 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73fb01b8d4762eb10ec48b0ba9dcbc1e = $(`&lt;div id=&quot;html_73fb01b8d4762eb10ec48b0ba9dcbc1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_908e0ec9abad35013b7d49def8156925.setContent(html_73fb01b8d4762eb10ec48b0ba9dcbc1e);
#
#
#
#         marker_bae23d1e6173ffffb02a2b4799604b4d.bindPopup(popup_908e0ec9abad35013b7d49def8156925)
#         ;
#
#
#
#
#             var marker_22f37017f9f0cff0bc63a04914817923 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_60e5b75535866f8af154717bfaf9e751);
#
#
#         var popup_79e53b7ef604d04e0e91be3f836709b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c3a2067bcc1d19685f64785bea4601d = $(`&lt;div id=&quot;html_2c3a2067bcc1d19685f64785bea4601d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_79e53b7ef604d04e0e91be3f836709b0.setContent(html_2c3a2067bcc1d19685f64785bea4601d);
#
#
#
#         marker_22f37017f9f0cff0bc63a04914817923.bindPopup(popup_79e53b7ef604d04e0e91be3f836709b0)
#         ;
#
#
#
#
#             var marker_81636bafc9ae4046393ea23e9c754093 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_60e5b75535866f8af154717bfaf9e751);
#
#
#         var popup_9d1749ef4a09a6614d805714c0809f73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_892bc5756fb33c78abc4fbc0dba5a9f3 = $(`&lt;div id=&quot;html_892bc5756fb33c78abc4fbc0dba5a9f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9d1749ef4a09a6614d805714c0809f73.setContent(html_892bc5756fb33c78abc4fbc0dba5a9f3);
#
#
#
#         marker_81636bafc9ae4046393ea23e9c754093.bindPopup(popup_9d1749ef4a09a6614d805714c0809f73)
#         ;
#
#
#
#
#             var marker_e457c074df306e8227eae7525a24cdc9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_60e5b75535866f8af154717bfaf9e751);
#
#
#         var popup_5d31ec51682093a8b1f07e4a1307665b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95be5d3056ab9c692b54c7a913cd3419 = $(`&lt;div id=&quot;html_95be5d3056ab9c692b54c7a913cd3419&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5d31ec51682093a8b1f07e4a1307665b.setContent(html_95be5d3056ab9c692b54c7a913cd3419);
#
#
#
#         marker_e457c074df306e8227eae7525a24cdc9.bindPopup(popup_5d31ec51682093a8b1f07e4a1307665b)
#         ;
#
#
#
#
#             var marker_4bc2957377629daf0ab004c227365c44 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_60e5b75535866f8af154717bfaf9e751);
#
#
#         var popup_1aa4dcf9c975a862931508862b06b799 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f83d54221a83b4bb715a352cd222cc0 = $(`&lt;div id=&quot;html_1f83d54221a83b4bb715a352cd222cc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1aa4dcf9c975a862931508862b06b799.setContent(html_1f83d54221a83b4bb715a352cd222cc0);
#
#
#
#         marker_4bc2957377629daf0ab004c227365c44.bindPopup(popup_1aa4dcf9c975a862931508862b06b799)
#         ;
#
#
#
#
#             var marker_0ae729e22a

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19a4ecd6a2142a5c28d6c271c363e41f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19a4ecd6a2142a5c28d6c271c363e41f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19a4ecd6a2142a5c28d6c271c363e41f = L.map(
#                 &quot;map_19a4ecd6a2142a5c28d6c271c363e41f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ebd89122ef467e2eba70625b683f23d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ebd89122ef467e2eba70625b683f23d4.addTo(map_19a4ecd6a2142a5c28d6c271c363e41f);
#
#
#             var feature_group_5ccb5b81c0addb17035304db74fa3247 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_05e21339001d0b88105e07c7a0ac6eea = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5ccb5b81c0addb17035304db74fa3247);
#
#
#         var popup_1e8ae59c45e7023370d15b5433aa6eee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a0e11fd0a307829e5837ca52bc68738 = $(`&lt;div id=&quot;html_7a0e11fd0a307829e5837ca52bc68738&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1e8ae59c45e7023370d15b5433aa6eee.setContent(html_7a0e11fd0a307829e5837ca52bc68738);
#
#
#
#         marker_05e21339001d0b88105e07c7a0ac6eea.bindPopup(popup_1e8ae59c45e7023370d15b5433aa6eee)
#         ;
#
#
#
#
#             var marker_607f568460cf94dfa95e9ab553dd3b43 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5ccb5b81c0addb17035304db74fa3247);
#
#
#         var popup_37207f5f18a793dd0d0a433800730ee0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7efb4bee4b02d254a39b13e57fc73f2b = $(`&lt;div id=&quot;html_7efb4bee4b02d254a39b13e57fc73f2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_37207f5f18a793dd0d0a433800730ee0.setContent(html_7efb4bee4b02d254a39b13e57fc73f2b);
#
#
#
#         marker_607f568460cf94dfa95e9ab553dd3b43.bindPopup(popup_37207f5f18a793dd0d0a433800730ee0)
#         ;
#
#
#
#
#             var marker_6dad6894a322c5dfca7c00d3c68dd216 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5ccb5b81c0addb17035304db74fa3247);
#
#
#         var popup_f4a8552bd7edf28d83599bd6b4efec25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bc0f59a9f5db254278d929a0fc5979f = $(`&lt;div id=&quot;html_2bc0f59a9f5db254278d929a0fc5979f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f4a8552bd7edf28d83599bd6b4efec25.setContent(html_2bc0f59a9f5db254278d929a0fc5979f);
#
#
#
#         marker_6dad6894a322c5dfca7c00d3c68dd216.bindPopup(popup_f4a8552bd7edf28d83599bd6b4efec25)
#         ;
#
#
#
#
#             var marker_a0601c2cb715099106bb60caf55faf90 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5ccb5b81c0addb17035304db74fa3247);
#
#
#         var popup_ee23dbbadd08c2327d06b5fc1644e45a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5523a35bfc2324307adc53cc02a249e9 = $(`&lt;div id=&quot;html_5523a35bfc2324307adc53cc02a249e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ee23dbbadd08c2327d06b5fc1644e45a.setContent(html_5523a35bfc2324307adc53cc02a249e9);
#
#
#
#         marker_a0601c2cb715099106bb60caf55faf90.bindPopup(popup_ee23dbbadd08c2327d06b5fc1644e45a)
#         ;
#
#
#
#
#             var marker_eb3335771182f16f7eca1c17cd4da69d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5ccb5b81c0addb17035304db74fa3247);
#
#
#         var popup_a669ce1afd56d85a86a75f90e48068e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_598db8ba2d65e9052915081e03b84ce0 = $(`&lt;div id=&quot;html_598db8ba2d65e9052915081e03b84ce0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_a669ce1afd56d85a86

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07983caa39b8b4db65aab653f4050800 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07983caa39b8b4db65aab653f4050800&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07983caa39b8b4db65aab653f4050800 = L.map(
#                 &quot;map_07983caa39b8b4db65aab653f4050800&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86008a39cf80d5b8b603dab31a60ca83 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_86008a39cf80d5b8b603dab31a60ca83.addTo(map_07983caa39b8b4db65aab653f4050800);
#
#
#             var feature_group_228c632754862cb0d38036b69eb32a22 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_228c632754862cb0d38036b69eb32a22.addTo(map_07983caa39b8b4db65aab653f4050800);
#
#
#             var feature_group_sub_group_bfcec187961b383befb0c5a1c95df10c = L.featureGroup.subGroup(
#                 feature_group_228c632754862cb0d38036b69eb32a22
#             );
#
#
#             var marker_e45f9c6e047f8348897802ab21e9e748 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bfcec187961b383befb0c5a1c95df10c);
#
#
#         var popup_2d278869fb181a42066b0d463b92c936 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68395af4d1abd5754e1c1dff99625837 = $(`&lt;div id=&quot;html_68395af4d1abd5754e1c1dff99625837&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2d278869fb181a42066b0d463b92c936.setContent(html_68395af4d1abd5754e1c1dff99625837);
#
#
#
#         marker_e45f9c6e047f8348897802ab21e9e748.bindPopup(popup_2d278869fb181a42066b0d463b92c936)
#         ;
#
#
#
#
#             var marker_f017e11fbd56d3c6b97118700bcfe47c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bfcec187961b383befb0c5a1c95df10c);
#
#
#         var popup_cc47f695f3dddbf5c89d68654e68d7cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_735b49effb28c7440c792300c3f3dc91 = $(`&lt;div id=&quot;html_735b49effb28c7440c792300c3f3dc91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cc47f695f3dddbf5c89d68654e68d7cc.setContent(html_735b49effb28c7440c792300c3f3dc91);
#
#
#
#         marker_f017e11fbd56d3c6b97118700bcfe47c.bindPopup(popup_cc47f695f3dddbf5c89d68654e68d7cc)
#         ;
#
#
#
#
#             var marker_cad8024f5bd6eb6805941f9ec7a21447 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bfcec187961b383befb0c5a1c95df10c);
#
#
#         var popup_18c1c313c8e8cd53ff96016378fd123a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1d8d243876481761547e555a2e3fd58 = $(`&lt;div id=&quot;html_f1d8d243876481761547e555a2e3fd58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_18c1c313c8e8cd53ff96016378fd123a.setContent(html_f1d8d243876481761547e555a2e3fd58);
#
#
#
#         marker_cad8024f5bd6eb6805941f9ec7a21447.bindPopup(popup_18c1c313c8e8cd53ff96016378fd123a)
#         ;
#
#
#
#
#             var marker_2f8672a6c0a6200c964c1ce7e662f3f6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bfcec187961b383befb0c5a1c95df10c);
#
#
#         var popup_4c9f464c4b9b1b7936f11ed46923bb1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92f5ea2a2632951126e26cbf27e900b7 = $(`&lt;div id=&quot;html_92f5ea2a2632951126e26cbf27e900b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4c9f464c4b9b1b7936f11ed46923bb1f.setContent(html_92f5ea2a2632951126e26cbf27e900b7);
#
#
#
#         marker_2f8672a6c0a6200c964c1ce7e662f3f6.bindPopup(popup_4c9f464c4b9b1b7936f11ed46923bb1f)
#         ;
#
#
#
#
#             var marker_74223ca74e607e1e920ac6c902aa2b1e = L.marker(
#                 [45.050399999999996, 3.0504],
