# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79751ee58bceacdc6448b563d2fd94e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79751ee58bceacdc6448b563d2fd94e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79751ee58bceacdc6448b563d2fd94e9 = L.map(
#                 &quot;map_79751ee58bceacdc6448b563d2fd94e9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce87c8139bf8e02c77377b92108254cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce87c8139bf8e02c77377b92108254cb.addTo(map_79751ee58bceacdc6448b563d2fd94e9);
#
#
#             var marker_536af0f608a822cddc516f7ef013172c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_79751ee58bceacdc6448b563d2fd94e9);
#
#
#         var popup_0f238632a17e38ca724b7dd275b50024 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_140898a8bcb2038ca665b917b11fa55b = $(`&lt;div id=&quot;html_140898a8bcb2038ca665b917b11fa55b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0f238632a17e38ca724b7dd275b50024.setContent(html_140898a8bcb2038ca665b917b11fa55b);
#
#
#
#         marker_536af0f608a822cddc516f7ef013172c.bindPopup(popup_0f238632a17e38ca724b7dd275b50024)
#         ;
#
#
#
#
#             var marker_f9f397d800847b4ca6202ea9eb0b8b7f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_79751ee58bceacdc6448b563d2fd94e9);
#
#
#         var popup_ea7d6762b6aeee43bf593248d1ba2af9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f124f7ce84c3612eed746e6d959bc178 = $(`&lt;div id=&quot;html_f124f7ce84c3612eed746e6d959bc178&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ea7d6762b6aeee43bf593248d1ba2af9.setContent(html_f124f7ce84c3612eed746e6d959bc178);
#
#
#
#         marker_f9f397d800847b4ca6202ea9eb0b8b7f.bindPopup(popup_ea7d6762b6aeee43bf593248d1ba2af9)
#         ;
#
#
#
#
#             var marker_e6f8e18994a854aa036477d09d5718e4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_79751ee58bceacdc6448b563d2fd94e9);
#
#
#         var popup_c22cf4adbaf9de844567d5c5e368b5b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c61d9581bb986d210ae4a62c7c07b095 = $(`&lt;div id=&quot;html_c61d9581bb986d210ae4a62c7c07b095&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c22cf4adbaf9de844567d5c5e368b5b9.setContent(html_c61d9581bb986d210ae4a62c7c07b095);
#
#
#
#         marker_e6f8e18994a854aa036477d09d5718e4.bindPopup(popup_c22cf4adbaf9de844567d5c5e368b5b9)
#         ;
#
#
#
#
#             var marker_d9751305a247314dd95b484ab4d37cbe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_79751ee58bceacdc6448b563d2fd94e9);
#
#
#         var popup_b62741f52348f5ed20703086e7dba430 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_355e963c8b6a1e855b3b343d2b71b63a = $(`&lt;div id=&quot;html_355e963c8b6a1e855b3b343d2b71b63a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b62741f52348f5ed20703086e7dba430.setContent(html_355e963c8b6a1e855b3b343d2b71b63a);
#
#
#
#         marker_d9751305a247314dd95b484ab4d37cbe.bindPopup(popup_b62741f52348f5ed20703086e7dba430)
#         ;
#
#
#
#
#             var marker_cd73076131548171a3ed11b21bddf4d0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_79751ee58bceacdc6448b563d2fd94e9);
#
#
#         var popup_41060b6cb5df35303d8bf33d127c0cc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91d97a121982de1602177a8461cbd704 = $(`&lt;div id=&quot;html_91d97a121982de1602177a8461cbd704&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_41060b6cb5df35303d8bf33d127c0cc5.setContent(html_91d97a121982de1602177a8461cbd704);
#
#
#
#         marker_cd73076131548171a3ed11b21bddf4d0.bindPopup(popup_41060b6cb5df35303d8bf33d127c0cc5)
#         ;
#
#
#
#
#             var marker_8ec8c13ebb

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9576a465cd2a8ca1e2d6213d4abe4d84 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9576a465cd2a8ca1e2d6213d4abe4d84&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9576a465cd2a8ca1e2d6213d4abe4d84 = L.map(
#                 &quot;map_9576a465cd2a8ca1e2d6213d4abe4d84&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4905a72dff2110d61ad1917359dac057 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4905a72dff2110d61ad1917359dac057.addTo(map_9576a465cd2a8ca1e2d6213d4abe4d84);
#
#
#             var feature_group_0b62dde44979952041213b33f7252f84 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5404cceea9aee392ebfc42e27e65e428 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0b62dde44979952041213b33f7252f84);
#
#
#         var popup_3ab0f4a859fd23308d6a92c101b8a1a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_835faf95463204388ac5ea64cb3b3e3e = $(`&lt;div id=&quot;html_835faf95463204388ac5ea64cb3b3e3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3ab0f4a859fd23308d6a92c101b8a1a3.setContent(html_835faf95463204388ac5ea64cb3b3e3e);
#
#
#
#         marker_5404cceea9aee392ebfc42e27e65e428.bindPopup(popup_3ab0f4a859fd23308d6a92c101b8a1a3)
#         ;
#
#
#
#
#             var marker_e541ae170616b31298c4188638205a39 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0b62dde44979952041213b33f7252f84);
#
#
#         var popup_42bef5cc4dce19cdd3f476d1a007f71a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c0b2fd1f1a418452fd4f4d566c6cebd = $(`&lt;div id=&quot;html_3c0b2fd1f1a418452fd4f4d566c6cebd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_42bef5cc4dce19cdd3f476d1a007f71a.setContent(html_3c0b2fd1f1a418452fd4f4d566c6cebd);
#
#
#
#         marker_e541ae170616b31298c4188638205a39.bindPopup(popup_42bef5cc4dce19cdd3f476d1a007f71a)
#         ;
#
#
#
#
#             var marker_0577c4601c39a41d01302900eb91b8f8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0b62dde44979952041213b33f7252f84);
#
#
#         var popup_760ca99795d5bc20a2fae784998e808b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06507343de983e7adc4c47ce68adc793 = $(`&lt;div id=&quot;html_06507343de983e7adc4c47ce68adc793&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_760ca99795d5bc20a2fae784998e808b.setContent(html_06507343de983e7adc4c47ce68adc793);
#
#
#
#         marker_0577c4601c39a41d01302900eb91b8f8.bindPopup(popup_760ca99795d5bc20a2fae784998e808b)
#         ;
#
#
#
#
#             var marker_a28ed8e46d32ffb6ffba6a81f0708a52 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0b62dde44979952041213b33f7252f84);
#
#
#         var popup_3c3255700dd2ba1b38317c04a9840703 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65a7c74dfae2f61c51b086c89869b24e = $(`&lt;div id=&quot;html_65a7c74dfae2f61c51b086c89869b24e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3c3255700dd2ba1b38317c04a9840703.setContent(html_65a7c74dfae2f61c51b086c89869b24e);
#
#
#
#         marker_a28ed8e46d32ffb6ffba6a81f0708a52.bindPopup(popup_3c3255700dd2ba1b38317c04a9840703)
#         ;
#
#
#
#
#             var marker_84cb46eb1c07729cf86f11afecd3d698 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0b62dde44979952041213b33f7252f84);
#
#
#         var popup_a1a0cbf65a22b4de1806e080dfa39f8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2ebc89efc68963b5e33d700da53a4a2 = $(`&lt;div id=&quot;html_a2ebc89efc68963b5e33d700da53a4a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_a1a0cbf65a22b4de18

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf7c9e81c7a9c967389975e7f2df0a2e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf7c9e81c7a9c967389975e7f2df0a2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf7c9e81c7a9c967389975e7f2df0a2e = L.map(
#                 &quot;map_bf7c9e81c7a9c967389975e7f2df0a2e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e87c6e5bafeaef42690f4d1588a56324 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e87c6e5bafeaef42690f4d1588a56324.addTo(map_bf7c9e81c7a9c967389975e7f2df0a2e);
#
#
#             var feature_group_51130e31fa7fd9ab5a13fb90c635e18b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_51130e31fa7fd9ab5a13fb90c635e18b.addTo(map_bf7c9e81c7a9c967389975e7f2df0a2e);
#
#
#             var feature_group_sub_group_780c102fd1ea9c3620ce678205905bfb = L.featureGroup.subGroup(
#                 feature_group_51130e31fa7fd9ab5a13fb90c635e18b
#             );
#
#
#             var marker_0924fc06f5d3ee975197f21d38719501 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_780c102fd1ea9c3620ce678205905bfb);
#
#
#         var popup_3bb94c7c4ad6ad497bf9dcfb6578763c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65c9e113b515f51d8528f3efe140161c = $(`&lt;div id=&quot;html_65c9e113b515f51d8528f3efe140161c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3bb94c7c4ad6ad497bf9dcfb6578763c.setContent(html_65c9e113b515f51d8528f3efe140161c);
#
#
#
#         marker_0924fc06f5d3ee975197f21d38719501.bindPopup(popup_3bb94c7c4ad6ad497bf9dcfb6578763c)
#         ;
#
#
#
#
#             var marker_7ba9542580a66297c2db7e16df36ed37 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_780c102fd1ea9c3620ce678205905bfb);
#
#
#         var popup_a0a2d11d34b1abbdd6c858e6b5a571e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05686d575b87b714edb6f766ab7df6c2 = $(`&lt;div id=&quot;html_05686d575b87b714edb6f766ab7df6c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a0a2d11d34b1abbdd6c858e6b5a571e7.setContent(html_05686d575b87b714edb6f766ab7df6c2);
#
#
#
#         marker_7ba9542580a66297c2db7e16df36ed37.bindPopup(popup_a0a2d11d34b1abbdd6c858e6b5a571e7)
#         ;
#
#
#
#
#             var marker_289502133f4d173d369de9babeeb8297 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_780c102fd1ea9c3620ce678205905bfb);
#
#
#         var popup_d4bc4d4b2257d0ed9aa2316d040618e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5f8fb6651e7079eb473036d1e63bf0d = $(`&lt;div id=&quot;html_c5f8fb6651e7079eb473036d1e63bf0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d4bc4d4b2257d0ed9aa2316d040618e5.setContent(html_c5f8fb6651e7079eb473036d1e63bf0d);
#
#
#
#         marker_289502133f4d173d369de9babeeb8297.bindPopup(popup_d4bc4d4b2257d0ed9aa2316d040618e5)
#         ;
#
#
#
#
#             var marker_bbef0d80944eeb496062e0e13d79e974 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_780c102fd1ea9c3620ce678205905bfb);
#
#
#         var popup_7b8e5e457691ecc680fe7cef3fa3a999 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_648013b24cd4f39cd1a1d58dcbb5caf5 = $(`&lt;div id=&quot;html_648013b24cd4f39cd1a1d58dcbb5caf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7b8e5e457691ecc680fe7cef3fa3a999.setContent(html_648013b24cd4f39cd1a1d58dcbb5caf5);
#
#
#
#         marker_bbef0d80944eeb496062e0e13d79e974.bindPopup(popup_7b8e5e457691ecc680fe7cef3fa3a999)
#         ;
#
#
#
#
#             var marker_f5e601d75ae8ff1338e56da65b660419 = L.marker(
#                 [45.050399999999996, 3.0504],
