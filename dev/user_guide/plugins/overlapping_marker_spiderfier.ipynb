# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97739cb0511da48c5287205d12218066 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97739cb0511da48c5287205d12218066&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97739cb0511da48c5287205d12218066 = L.map(
#                 &quot;map_97739cb0511da48c5287205d12218066&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ca7f9278b96147d1e2de2c67abd1e5c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0ca7f9278b96147d1e2de2c67abd1e5c.addTo(map_97739cb0511da48c5287205d12218066);
#
#
#             var marker_3cccefc41c473e2fa07539a0253966e2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_97739cb0511da48c5287205d12218066);
#
#
#         var popup_e071708d6f1548c5118129ae77f8763b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01208343805dd931a39b6ec135c31659 = $(`&lt;div id=&quot;html_01208343805dd931a39b6ec135c31659&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e071708d6f1548c5118129ae77f8763b.setContent(html_01208343805dd931a39b6ec135c31659);
#
#
#
#         marker_3cccefc41c473e2fa07539a0253966e2.bindPopup(popup_e071708d6f1548c5118129ae77f8763b)
#         ;
#
#
#
#
#             var marker_a456a422f012c86f1c4b4de29631ed92 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_97739cb0511da48c5287205d12218066);
#
#
#         var popup_fef04f70f186ddf88a5560875edff82c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f049f141028b410a6c809522fe2f0b03 = $(`&lt;div id=&quot;html_f049f141028b410a6c809522fe2f0b03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_fef04f70f186ddf88a5560875edff82c.setContent(html_f049f141028b410a6c809522fe2f0b03);
#
#
#
#         marker_a456a422f012c86f1c4b4de29631ed92.bindPopup(popup_fef04f70f186ddf88a5560875edff82c)
#         ;
#
#
#
#
#             var marker_af66f99031adb8b954e0c50d0036a3c3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_97739cb0511da48c5287205d12218066);
#
#
#         var popup_794380c294bf91c657a156dae5940ac4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2dcaa046596c85eaa9eee442f106ae08 = $(`&lt;div id=&quot;html_2dcaa046596c85eaa9eee442f106ae08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_794380c294bf91c657a156dae5940ac4.setContent(html_2dcaa046596c85eaa9eee442f106ae08);
#
#
#
#         marker_af66f99031adb8b954e0c50d0036a3c3.bindPopup(popup_794380c294bf91c657a156dae5940ac4)
#         ;
#
#
#
#
#             var marker_6467b5f1139d62d98508f12c03ef79a9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_97739cb0511da48c5287205d12218066);
#
#
#         var popup_9f6f722150756f8b07ce2312f2c0ec1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_434d36f9ddad06c56f937caa78a6a3f1 = $(`&lt;div id=&quot;html_434d36f9ddad06c56f937caa78a6a3f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9f6f722150756f8b07ce2312f2c0ec1d.setContent(html_434d36f9ddad06c56f937caa78a6a3f1);
#
#
#
#         marker_6467b5f1139d62d98508f12c03ef79a9.bindPopup(popup_9f6f722150756f8b07ce2312f2c0ec1d)
#         ;
#
#
#
#
#             var marker_d361f6716f7690542546169c43fdc57d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_97739cb0511da48c5287205d12218066);
#
#
#         var popup_fcc43ac0988b2ea3f31297af1c4b3700 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5757238a8a38eb69ca86003acc57cbbf = $(`&lt;div id=&quot;html_5757238a8a38eb69ca86003acc57cbbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fcc43ac0988b2ea3f31297af1c4b3700.setContent(html_5757238a8a38eb69ca86003acc57cbbf);
#
#
#
#         marker_d361f6716f7690542546169c43fdc57d.bindPopup(popup_fcc43ac0988b2ea3f31297af1c4b3700)
#         ;
#
#
#
#
#             var marker_168ecf932d

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bdb3f50590d3d893115971443fe03b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bdb3f50590d3d893115971443fe03b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bdb3f50590d3d893115971443fe03b7 = L.map(
#                 &quot;map_3bdb3f50590d3d893115971443fe03b7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9bab80c1a0f7df3372664f40851d7566 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9bab80c1a0f7df3372664f40851d7566.addTo(map_3bdb3f50590d3d893115971443fe03b7);
#
#
#             var feature_group_002dee3f443d8de6b8a3e16f3ea11c9b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2a89abf817d957f590f1d34413f1448b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_002dee3f443d8de6b8a3e16f3ea11c9b);
#
#
#         var popup_8f7de049c712832c07c456737766e67f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5a864c4ca00ce16772d77aa3ff1ed61 = $(`&lt;div id=&quot;html_e5a864c4ca00ce16772d77aa3ff1ed61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8f7de049c712832c07c456737766e67f.setContent(html_e5a864c4ca00ce16772d77aa3ff1ed61);
#
#
#
#         marker_2a89abf817d957f590f1d34413f1448b.bindPopup(popup_8f7de049c712832c07c456737766e67f)
#         ;
#
#
#
#
#             var marker_ce1a0cf3a1ef08e098dca1570cb990e5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_002dee3f443d8de6b8a3e16f3ea11c9b);
#
#
#         var popup_91bc11e8331d61410d20bb8bce321afe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09e446392e32ad89896961ce711bdb42 = $(`&lt;div id=&quot;html_09e446392e32ad89896961ce711bdb42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_91bc11e8331d61410d20bb8bce321afe.setContent(html_09e446392e32ad89896961ce711bdb42);
#
#
#
#         marker_ce1a0cf3a1ef08e098dca1570cb990e5.bindPopup(popup_91bc11e8331d61410d20bb8bce321afe)
#         ;
#
#
#
#
#             var marker_6ff6f55b1192ef62281d4c7816a689be = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_002dee3f443d8de6b8a3e16f3ea11c9b);
#
#
#         var popup_24bb849d8e38b23fc290363760483318 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da870d88173863411d2d5ceb494b62cf = $(`&lt;div id=&quot;html_da870d88173863411d2d5ceb494b62cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_24bb849d8e38b23fc290363760483318.setContent(html_da870d88173863411d2d5ceb494b62cf);
#
#
#
#         marker_6ff6f55b1192ef62281d4c7816a689be.bindPopup(popup_24bb849d8e38b23fc290363760483318)
#         ;
#
#
#
#
#             var marker_8044e6780dca45f5efe42fef6f5f82b3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_002dee3f443d8de6b8a3e16f3ea11c9b);
#
#
#         var popup_a514f5b910ba92d17773348b78b334f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f36d5236264c555cb8dfdb8107e281d = $(`&lt;div id=&quot;html_1f36d5236264c555cb8dfdb8107e281d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a514f5b910ba92d17773348b78b334f2.setContent(html_1f36d5236264c555cb8dfdb8107e281d);
#
#
#
#         marker_8044e6780dca45f5efe42fef6f5f82b3.bindPopup(popup_a514f5b910ba92d17773348b78b334f2)
#         ;
#
#
#
#
#             var marker_b012caae626df994d93ce067acfe49bf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_002dee3f443d8de6b8a3e16f3ea11c9b);
#
#
#         var popup_f3af6090180aa4b2d75411c562d73361 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b70768e80599c8585d334db384d24dc6 = $(`&lt;div id=&quot;html_b70768e80599c8585d334db384d24dc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_f3af6090180aa4b2d7

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfdc1d4e2b51747c2328370f645a3c2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfdc1d4e2b51747c2328370f645a3c2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfdc1d4e2b51747c2328370f645a3c2b = L.map(
#                 &quot;map_dfdc1d4e2b51747c2328370f645a3c2b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_501330cfed3e64761e12f7daff7b9d59 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_501330cfed3e64761e12f7daff7b9d59.addTo(map_dfdc1d4e2b51747c2328370f645a3c2b);
#
#
#             var feature_group_85ef7fcb192b7a9990033a9e46a16d79 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_85ef7fcb192b7a9990033a9e46a16d79.addTo(map_dfdc1d4e2b51747c2328370f645a3c2b);
#
#
#             var feature_group_sub_group_49d5354180a93cc2195ddddfb29bd4fd = L.featureGroup.subGroup(
#                 feature_group_85ef7fcb192b7a9990033a9e46a16d79
#             );
#
#
#             var marker_e6bf1fca9b2843a190edd24a07dfc71e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_49d5354180a93cc2195ddddfb29bd4fd);
#
#
#         var popup_2cbef0f3cc829b9a4f6a236bb87a7d1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_903b3f2f3bb3e21d5757fece9193069f = $(`&lt;div id=&quot;html_903b3f2f3bb3e21d5757fece9193069f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2cbef0f3cc829b9a4f6a236bb87a7d1b.setContent(html_903b3f2f3bb3e21d5757fece9193069f);
#
#
#
#         marker_e6bf1fca9b2843a190edd24a07dfc71e.bindPopup(popup_2cbef0f3cc829b9a4f6a236bb87a7d1b)
#         ;
#
#
#
#
#             var marker_ec1759e49ec7e947fca8b8388f691988 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_49d5354180a93cc2195ddddfb29bd4fd);
#
#
#         var popup_f16200e5a4f49ca9ad6147ea99136958 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aee8667e8ec98ffe57269284f388e841 = $(`&lt;div id=&quot;html_aee8667e8ec98ffe57269284f388e841&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f16200e5a4f49ca9ad6147ea99136958.setContent(html_aee8667e8ec98ffe57269284f388e841);
#
#
#
#         marker_ec1759e49ec7e947fca8b8388f691988.bindPopup(popup_f16200e5a4f49ca9ad6147ea99136958)
#         ;
#
#
#
#
#             var marker_99f7099e6b914e4384b64c6a727d0206 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_49d5354180a93cc2195ddddfb29bd4fd);
#
#
#         var popup_5342d9104c91c152fbd0e6ac99487be3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5427257586516cb297f19b92cd59a789 = $(`&lt;div id=&quot;html_5427257586516cb297f19b92cd59a789&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5342d9104c91c152fbd0e6ac99487be3.setContent(html_5427257586516cb297f19b92cd59a789);
#
#
#
#         marker_99f7099e6b914e4384b64c6a727d0206.bindPopup(popup_5342d9104c91c152fbd0e6ac99487be3)
#         ;
#
#
#
#
#             var marker_5d81255e0eb09f89d68f4e58de0b57f8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_49d5354180a93cc2195ddddfb29bd4fd);
#
#
#         var popup_ceb343ca379d250402ce998f22ffa175 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_153d66170328a1252b010e096f4e1c97 = $(`&lt;div id=&quot;html_153d66170328a1252b010e096f4e1c97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ceb343ca379d250402ce998f22ffa175.setContent(html_153d66170328a1252b010e096f4e1c97);
#
#
#
#         marker_5d81255e0eb09f89d68f4e58de0b57f8.bindPopup(popup_ceb343ca379d250402ce998f22ffa175)
#         ;
#
#
#
#
#             var marker_067a769ba97eba326757dadaeeafa858 = L.marker(
#                 [45.050399999999996, 3.0504],
