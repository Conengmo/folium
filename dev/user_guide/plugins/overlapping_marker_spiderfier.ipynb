# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56b95fa3ffb3f932b477a7fe2ffc6078 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56b95fa3ffb3f932b477a7fe2ffc6078&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56b95fa3ffb3f932b477a7fe2ffc6078 = L.map(
#                 &quot;map_56b95fa3ffb3f932b477a7fe2ffc6078&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e3dda12585900f449510c3b71ae5122 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e3dda12585900f449510c3b71ae5122.addTo(map_56b95fa3ffb3f932b477a7fe2ffc6078);
#
#
#             var marker_0ad4630c4cf05b7827006bcb1931ec82 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_56b95fa3ffb3f932b477a7fe2ffc6078);
#
#
#         var popup_d35867e549ad03171dde9eb6899d71f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca9a849cfa2e861957025811feec2e34 = $(`&lt;div id=&quot;html_ca9a849cfa2e861957025811feec2e34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d35867e549ad03171dde9eb6899d71f9.setContent(html_ca9a849cfa2e861957025811feec2e34);
#
#
#
#         marker_0ad4630c4cf05b7827006bcb1931ec82.bindPopup(popup_d35867e549ad03171dde9eb6899d71f9)
#         ;
#
#
#
#
#             var marker_08f5d4689fd96f6beaa20a073026bf80 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_56b95fa3ffb3f932b477a7fe2ffc6078);
#
#
#         var popup_390d8ee6e4abaf83ade09fc81e231cb6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14821af23037bb3294fbeb113c0108bb = $(`&lt;div id=&quot;html_14821af23037bb3294fbeb113c0108bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_390d8ee6e4abaf83ade09fc81e231cb6.setContent(html_14821af23037bb3294fbeb113c0108bb);
#
#
#
#         marker_08f5d4689fd96f6beaa20a073026bf80.bindPopup(popup_390d8ee6e4abaf83ade09fc81e231cb6)
#         ;
#
#
#
#
#             var marker_bc46d4c94d1eadfb48123490288079f6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_56b95fa3ffb3f932b477a7fe2ffc6078);
#
#
#         var popup_069ea213554d1ca5ef5ee1016c1445e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a2d724cd36633abeeb90a0e90778c35 = $(`&lt;div id=&quot;html_9a2d724cd36633abeeb90a0e90778c35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_069ea213554d1ca5ef5ee1016c1445e8.setContent(html_9a2d724cd36633abeeb90a0e90778c35);
#
#
#
#         marker_bc46d4c94d1eadfb48123490288079f6.bindPopup(popup_069ea213554d1ca5ef5ee1016c1445e8)
#         ;
#
#
#
#
#             var marker_e2248fa080d5285f16e3f8fa9ef17650 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_56b95fa3ffb3f932b477a7fe2ffc6078);
#
#
#         var popup_f36de57ac5be439fc46454514c215b7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81482578cee5f7550ee719ce1cbacec2 = $(`&lt;div id=&quot;html_81482578cee5f7550ee719ce1cbacec2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f36de57ac5be439fc46454514c215b7f.setContent(html_81482578cee5f7550ee719ce1cbacec2);
#
#
#
#         marker_e2248fa080d5285f16e3f8fa9ef17650.bindPopup(popup_f36de57ac5be439fc46454514c215b7f)
#         ;
#
#
#
#
#             var marker_e7609cc8f563114ce2a737e99e7dfcce = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_56b95fa3ffb3f932b477a7fe2ffc6078);
#
#
#         var popup_d688198a46d7e383c06867237fb48c9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26055bdc80bbfbd3d2686cc66196cd5f = $(`&lt;div id=&quot;html_26055bdc80bbfbd3d2686cc66196cd5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d688198a46d7e383c06867237fb48c9b.setContent(html_26055bdc80bbfbd3d2686cc66196cd5f);
#
#
#
#         marker_e7609cc8f563114ce2a737e99e7dfcce.bindPopup(popup_d688198a46d7e383c06867237fb48c9b)
#         ;
#
#
#
#
#             var marker_2adcc8dec9

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72eb15f7e5a4de660fc7a7ef34ad9f9c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72eb15f7e5a4de660fc7a7ef34ad9f9c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_72eb15f7e5a4de660fc7a7ef34ad9f9c = L.map(
#                 &quot;map_72eb15f7e5a4de660fc7a7ef34ad9f9c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f97d6c1bcfad88dbeb1fde5bec60796c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f97d6c1bcfad88dbeb1fde5bec60796c.addTo(map_72eb15f7e5a4de660fc7a7ef34ad9f9c);
#
#
#             var feature_group_286aa2d4a132c588b5e9827912d6586b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5ef50412981854ffbd8cf3b306c7222b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_286aa2d4a132c588b5e9827912d6586b);
#
#
#         var popup_7edf82c8008ed814c976859b35893f87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0dbdb4e56541ed33fbe79fa8abe7c5bd = $(`&lt;div id=&quot;html_0dbdb4e56541ed33fbe79fa8abe7c5bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7edf82c8008ed814c976859b35893f87.setContent(html_0dbdb4e56541ed33fbe79fa8abe7c5bd);
#
#
#
#         marker_5ef50412981854ffbd8cf3b306c7222b.bindPopup(popup_7edf82c8008ed814c976859b35893f87)
#         ;
#
#
#
#
#             var marker_be38bec75560a70b0dc90119ee2c06c9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_286aa2d4a132c588b5e9827912d6586b);
#
#
#         var popup_47d2257ae0b3c1b03e413783f06f95ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_859fe133bf9bae1d855b349352c28b1f = $(`&lt;div id=&quot;html_859fe133bf9bae1d855b349352c28b1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_47d2257ae0b3c1b03e413783f06f95ec.setContent(html_859fe133bf9bae1d855b349352c28b1f);
#
#
#
#         marker_be38bec75560a70b0dc90119ee2c06c9.bindPopup(popup_47d2257ae0b3c1b03e413783f06f95ec)
#         ;
#
#
#
#
#             var marker_2a06e8dab00d7cc4b5e84f754c431cf6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_286aa2d4a132c588b5e9827912d6586b);
#
#
#         var popup_aac7a94dd237c63db72a39d504e3f4d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11e7f4755a6f9f41f01a686d5bb86cbf = $(`&lt;div id=&quot;html_11e7f4755a6f9f41f01a686d5bb86cbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_aac7a94dd237c63db72a39d504e3f4d3.setContent(html_11e7f4755a6f9f41f01a686d5bb86cbf);
#
#
#
#         marker_2a06e8dab00d7cc4b5e84f754c431cf6.bindPopup(popup_aac7a94dd237c63db72a39d504e3f4d3)
#         ;
#
#
#
#
#             var marker_bb0208cd3faa39e350530cadd4f89827 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_286aa2d4a132c588b5e9827912d6586b);
#
#
#         var popup_9dd3e237d6724ecfae08e7d313acf817 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e98c5da84dabf3423d244e6a135655b8 = $(`&lt;div id=&quot;html_e98c5da84dabf3423d244e6a135655b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9dd3e237d6724ecfae08e7d313acf817.setContent(html_e98c5da84dabf3423d244e6a135655b8);
#
#
#
#         marker_bb0208cd3faa39e350530cadd4f89827.bindPopup(popup_9dd3e237d6724ecfae08e7d313acf817)
#         ;
#
#
#
#
#             var marker_0784c3e67aaa16c16891ccd95d5e52b0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_286aa2d4a132c588b5e9827912d6586b);
#
#
#         var popup_055619720d750ddc522d184a147a93c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2a06854a771ab8f3f96278e04e21b3c = $(`&lt;div id=&quot;html_f2a06854a771ab8f3f96278e04e21b3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_055619720d750ddc52

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74dc77d3762d2cb3bcd0e09e38b3337b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74dc77d3762d2cb3bcd0e09e38b3337b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74dc77d3762d2cb3bcd0e09e38b3337b = L.map(
#                 &quot;map_74dc77d3762d2cb3bcd0e09e38b3337b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bdcfd23437a8452fde18617da039893f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bdcfd23437a8452fde18617da039893f.addTo(map_74dc77d3762d2cb3bcd0e09e38b3337b);
#
#
#             var feature_group_93345384cc8c2351d2d87f3f13c14158 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_93345384cc8c2351d2d87f3f13c14158.addTo(map_74dc77d3762d2cb3bcd0e09e38b3337b);
#
#
#             var feature_group_sub_group_aba3be818869129d0d8849a65a6d64fc = L.featureGroup.subGroup(
#                 feature_group_93345384cc8c2351d2d87f3f13c14158
#             );
#
#
#             var marker_645846a9531a0edf6fca96b8ab2c8260 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_aba3be818869129d0d8849a65a6d64fc);
#
#
#         var popup_cf0b4b6deafc10660733e3c82f9adecc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d29b0ed9d65a08dfba9715a9184fd7bf = $(`&lt;div id=&quot;html_d29b0ed9d65a08dfba9715a9184fd7bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cf0b4b6deafc10660733e3c82f9adecc.setContent(html_d29b0ed9d65a08dfba9715a9184fd7bf);
#
#
#
#         marker_645846a9531a0edf6fca96b8ab2c8260.bindPopup(popup_cf0b4b6deafc10660733e3c82f9adecc)
#         ;
#
#
#
#
#             var marker_49e742304c55bffbdd4e55a18b1bb4ab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_aba3be818869129d0d8849a65a6d64fc);
#
#
#         var popup_9c824c3739deab3bbb6c4ca333a6a0d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6fd8062831e69812559dda4264d8383 = $(`&lt;div id=&quot;html_f6fd8062831e69812559dda4264d8383&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9c824c3739deab3bbb6c4ca333a6a0d0.setContent(html_f6fd8062831e69812559dda4264d8383);
#
#
#
#         marker_49e742304c55bffbdd4e55a18b1bb4ab.bindPopup(popup_9c824c3739deab3bbb6c4ca333a6a0d0)
#         ;
#
#
#
#
#             var marker_d6152574d6465124c90d3f42245c0e26 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_aba3be818869129d0d8849a65a6d64fc);
#
#
#         var popup_4581e946bbc7857321f5638f8d965eb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c75f8d0d6ee21d1ffb13329a5417833 = $(`&lt;div id=&quot;html_0c75f8d0d6ee21d1ffb13329a5417833&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4581e946bbc7857321f5638f8d965eb3.setContent(html_0c75f8d0d6ee21d1ffb13329a5417833);
#
#
#
#         marker_d6152574d6465124c90d3f42245c0e26.bindPopup(popup_4581e946bbc7857321f5638f8d965eb3)
#         ;
#
#
#
#
#             var marker_faf6f2a4de78de4cc251f393636e6ab9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_aba3be818869129d0d8849a65a6d64fc);
#
#
#         var popup_b864453d1a2d4607f7a2d59dab22a837 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ad19cdec2fbc11745e06d39bbee43f5 = $(`&lt;div id=&quot;html_2ad19cdec2fbc11745e06d39bbee43f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b864453d1a2d4607f7a2d59dab22a837.setContent(html_2ad19cdec2fbc11745e06d39bbee43f5);
#
#
#
#         marker_faf6f2a4de78de4cc251f393636e6ab9.bindPopup(popup_b864453d1a2d4607f7a2d59dab22a837)
#         ;
#
#
#
#
#             var marker_3955d3a85384b24dc691fc11cba52c92 = L.marker(
#                 [45.050399999999996, 3.0504],
