# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63a3b2844cb64d7ceda0dba4fd22a144 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63a3b2844cb64d7ceda0dba4fd22a144&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63a3b2844cb64d7ceda0dba4fd22a144 = L.map(
#                 &quot;map_63a3b2844cb64d7ceda0dba4fd22a144&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_677eda2982e6c1856f47915f58e40d3f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_677eda2982e6c1856f47915f58e40d3f.addTo(map_63a3b2844cb64d7ceda0dba4fd22a144);
#
#
#             var marker_1ec57c6803610c451ae327fe7cfdefa2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_63a3b2844cb64d7ceda0dba4fd22a144);
#
#
#         var popup_b0eea7e066348be98c21668774cd5695 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68effeb678affeb35585a2d37df114ae = $(`&lt;div id=&quot;html_68effeb678affeb35585a2d37df114ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b0eea7e066348be98c21668774cd5695.setContent(html_68effeb678affeb35585a2d37df114ae);
#
#
#
#         marker_1ec57c6803610c451ae327fe7cfdefa2.bindPopup(popup_b0eea7e066348be98c21668774cd5695)
#         ;
#
#
#
#
#             var marker_ba49c4d9b70c3155184a60ab1ccebdb4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_63a3b2844cb64d7ceda0dba4fd22a144);
#
#
#         var popup_8e131e3f8b3beec0ac6960b85c1e5ca9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f11742b626b57fb6dbd841d4c67883d0 = $(`&lt;div id=&quot;html_f11742b626b57fb6dbd841d4c67883d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8e131e3f8b3beec0ac6960b85c1e5ca9.setContent(html_f11742b626b57fb6dbd841d4c67883d0);
#
#
#
#         marker_ba49c4d9b70c3155184a60ab1ccebdb4.bindPopup(popup_8e131e3f8b3beec0ac6960b85c1e5ca9)
#         ;
#
#
#
#
#             var marker_2bb094b1fb78f4b9f870516b8b39c308 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_63a3b2844cb64d7ceda0dba4fd22a144);
#
#
#         var popup_1e8452bf34908a2bb34347c637c315cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f033e2565fb7815dbac9f203bc634b6a = $(`&lt;div id=&quot;html_f033e2565fb7815dbac9f203bc634b6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1e8452bf34908a2bb34347c637c315cc.setContent(html_f033e2565fb7815dbac9f203bc634b6a);
#
#
#
#         marker_2bb094b1fb78f4b9f870516b8b39c308.bindPopup(popup_1e8452bf34908a2bb34347c637c315cc)
#         ;
#
#
#
#
#             var marker_0da9230137e0daea15703269b39e8b85 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_63a3b2844cb64d7ceda0dba4fd22a144);
#
#
#         var popup_e0f660ca750c67035267944265e63669 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c989e858bf607b9783d19e18fb0930bd = $(`&lt;div id=&quot;html_c989e858bf607b9783d19e18fb0930bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e0f660ca750c67035267944265e63669.setContent(html_c989e858bf607b9783d19e18fb0930bd);
#
#
#
#         marker_0da9230137e0daea15703269b39e8b85.bindPopup(popup_e0f660ca750c67035267944265e63669)
#         ;
#
#
#
#
#             var marker_25c88bf0cdf8bf0b8ddfee5cb24e03eb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_63a3b2844cb64d7ceda0dba4fd22a144);
#
#
#         var popup_354214d38a6f3a52a1d559039ea758fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2dfcdefdafda4bbeab75c145aa65e6e = $(`&lt;div id=&quot;html_a2dfcdefdafda4bbeab75c145aa65e6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_354214d38a6f3a52a1d559039ea758fe.setContent(html_a2dfcdefdafda4bbeab75c145aa65e6e);
#
#
#
#         marker_25c88bf0cdf8bf0b8ddfee5cb24e03eb.bindPopup(popup_354214d38a6f3a52a1d559039ea758fe)
#         ;
#
#
#
#
#             var marker_74cf55fd52

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_334bb79707a9b2f25fedcaaedb330465 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_334bb79707a9b2f25fedcaaedb330465&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_334bb79707a9b2f25fedcaaedb330465 = L.map(
#                 &quot;map_334bb79707a9b2f25fedcaaedb330465&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55a4623478526eb8b02b0ed15d9ba1e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_55a4623478526eb8b02b0ed15d9ba1e0.addTo(map_334bb79707a9b2f25fedcaaedb330465);
#
#
#             var feature_group_3463eaa35954518e394950ba2353f8ed = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8e75bc59cadf2d55210f7ab0ab2c813d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3463eaa35954518e394950ba2353f8ed);
#
#
#         var popup_2f483974d2d11b0c35ac01e5079c5349 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a5f58a458887ab9e6ffdf67c4710934 = $(`&lt;div id=&quot;html_0a5f58a458887ab9e6ffdf67c4710934&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2f483974d2d11b0c35ac01e5079c5349.setContent(html_0a5f58a458887ab9e6ffdf67c4710934);
#
#
#
#         marker_8e75bc59cadf2d55210f7ab0ab2c813d.bindPopup(popup_2f483974d2d11b0c35ac01e5079c5349)
#         ;
#
#
#
#
#             var marker_0bb46f16cef25ddf00e5fb6bd7b0c14f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3463eaa35954518e394950ba2353f8ed);
#
#
#         var popup_0503c3786655f7d6ff3847489b1e5d4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_990e1fad207f24ee2b77c610f74b8ed4 = $(`&lt;div id=&quot;html_990e1fad207f24ee2b77c610f74b8ed4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0503c3786655f7d6ff3847489b1e5d4d.setContent(html_990e1fad207f24ee2b77c610f74b8ed4);
#
#
#
#         marker_0bb46f16cef25ddf00e5fb6bd7b0c14f.bindPopup(popup_0503c3786655f7d6ff3847489b1e5d4d)
#         ;
#
#
#
#
#             var marker_da8bb231e71683ebd7b4c3bc0aebf872 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3463eaa35954518e394950ba2353f8ed);
#
#
#         var popup_23e05abba1aad3ce39343512037b7edd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_895c90fa42d99fea7914daaf019a6c15 = $(`&lt;div id=&quot;html_895c90fa42d99fea7914daaf019a6c15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_23e05abba1aad3ce39343512037b7edd.setContent(html_895c90fa42d99fea7914daaf019a6c15);
#
#
#
#         marker_da8bb231e71683ebd7b4c3bc0aebf872.bindPopup(popup_23e05abba1aad3ce39343512037b7edd)
#         ;
#
#
#
#
#             var marker_b82bb6665be752708a1a4fc0129a993a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3463eaa35954518e394950ba2353f8ed);
#
#
#         var popup_3e763f5f1206c846c9caabacbd5718c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36f6f045b51f53e2f13dbe8843e1bc20 = $(`&lt;div id=&quot;html_36f6f045b51f53e2f13dbe8843e1bc20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3e763f5f1206c846c9caabacbd5718c7.setContent(html_36f6f045b51f53e2f13dbe8843e1bc20);
#
#
#
#         marker_b82bb6665be752708a1a4fc0129a993a.bindPopup(popup_3e763f5f1206c846c9caabacbd5718c7)
#         ;
#
#
#
#
#             var marker_be28ee4b7e1fc67760e832c41053d05e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3463eaa35954518e394950ba2353f8ed);
#
#
#         var popup_c85ff297377edc9cf5351cb29ec02088 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b4b08e6c40d778e365c59462ebf6ac6 = $(`&lt;div id=&quot;html_0b4b08e6c40d778e365c59462ebf6ac6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_c85ff297377edc9cf5

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b94043fe07fbafcc71c7e88809264e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b94043fe07fbafcc71c7e88809264e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b94043fe07fbafcc71c7e88809264e1 = L.map(
#                 &quot;map_3b94043fe07fbafcc71c7e88809264e1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1b78afa489597b43415fc2e8b5c7206 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a1b78afa489597b43415fc2e8b5c7206.addTo(map_3b94043fe07fbafcc71c7e88809264e1);
#
#
#             var feature_group_cc4a969f40fc957a12b78f4f6bdce93d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cc4a969f40fc957a12b78f4f6bdce93d.addTo(map_3b94043fe07fbafcc71c7e88809264e1);
#
#
#             var feature_group_sub_group_53f88df3f4b83269dd812c5ca4872765 = L.featureGroup.subGroup(
#                 feature_group_cc4a969f40fc957a12b78f4f6bdce93d
#             );
#
#
#             var marker_8d26b647d8562a501a56bd21a747922a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_53f88df3f4b83269dd812c5ca4872765);
#
#
#         var popup_19cc1818d0da3ec58b923bab4e963768 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57b20ef3e4e7fed951fc2e95c092f6a6 = $(`&lt;div id=&quot;html_57b20ef3e4e7fed951fc2e95c092f6a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_19cc1818d0da3ec58b923bab4e963768.setContent(html_57b20ef3e4e7fed951fc2e95c092f6a6);
#
#
#
#         marker_8d26b647d8562a501a56bd21a747922a.bindPopup(popup_19cc1818d0da3ec58b923bab4e963768)
#         ;
#
#
#
#
#             var marker_536158b3c8a98be76ea47c0fe3d75d82 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_53f88df3f4b83269dd812c5ca4872765);
#
#
#         var popup_ae613f53f10c7d4f56a25de882e0dd38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4a8f951bf2ec81aa78aacbbbf595d9e = $(`&lt;div id=&quot;html_e4a8f951bf2ec81aa78aacbbbf595d9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ae613f53f10c7d4f56a25de882e0dd38.setContent(html_e4a8f951bf2ec81aa78aacbbbf595d9e);
#
#
#
#         marker_536158b3c8a98be76ea47c0fe3d75d82.bindPopup(popup_ae613f53f10c7d4f56a25de882e0dd38)
#         ;
#
#
#
#
#             var marker_d00f0957d43374a422bc974a8eb73d9f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_53f88df3f4b83269dd812c5ca4872765);
#
#
#         var popup_6ee3a0f9cb0fde1c853b294e4157d99e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a153cac48465e49ea4e46a4d19dbf2af = $(`&lt;div id=&quot;html_a153cac48465e49ea4e46a4d19dbf2af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6ee3a0f9cb0fde1c853b294e4157d99e.setContent(html_a153cac48465e49ea4e46a4d19dbf2af);
#
#
#
#         marker_d00f0957d43374a422bc974a8eb73d9f.bindPopup(popup_6ee3a0f9cb0fde1c853b294e4157d99e)
#         ;
#
#
#
#
#             var marker_f58507bdf88812eb4ea2c089f8cf0abf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_53f88df3f4b83269dd812c5ca4872765);
#
#
#         var popup_9c60c71a3e116bd11c2b28ed40610b4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54c8421402db30552185b573f9afa2f8 = $(`&lt;div id=&quot;html_54c8421402db30552185b573f9afa2f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9c60c71a3e116bd11c2b28ed40610b4c.setContent(html_54c8421402db30552185b573f9afa2f8);
#
#
#
#         marker_f58507bdf88812eb4ea2c089f8cf0abf.bindPopup(popup_9c60c71a3e116bd11c2b28ed40610b4c)
#         ;
#
#
#
#
#             var marker_4638c16f6219bf41ff26e98d7bdf8789 = L.marker(
#                 [45.050399999999996, 3.0504],
