# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a62117c69d8a2241e64ba18818bbdb34 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a62117c69d8a2241e64ba18818bbdb34&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a62117c69d8a2241e64ba18818bbdb34 = L.map(
#                 &quot;map_a62117c69d8a2241e64ba18818bbdb34&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7fd2161335fb98776f7c15d6338130ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7fd2161335fb98776f7c15d6338130ee.addTo(map_a62117c69d8a2241e64ba18818bbdb34);
#
#
#             var marker_f02bd72d8a9c455834f76482761ed332 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a62117c69d8a2241e64ba18818bbdb34);
#
#
#         var popup_ff227deccfd2456181e04486c2562fdb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc2a7e582eefc75bceacfd20b83ae9e9 = $(`&lt;div id=&quot;html_fc2a7e582eefc75bceacfd20b83ae9e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ff227deccfd2456181e04486c2562fdb.setContent(html_fc2a7e582eefc75bceacfd20b83ae9e9);
#
#
#
#         marker_f02bd72d8a9c455834f76482761ed332.bindPopup(popup_ff227deccfd2456181e04486c2562fdb)
#         ;
#
#
#
#
#             var marker_c0cb72c8c185b7563c1b6819f31d279f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a62117c69d8a2241e64ba18818bbdb34);
#
#
#         var popup_c28d61a302cbe74aed13f8761b1ad94d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9b3cf18607b2badcd27cbf5f5a14005 = $(`&lt;div id=&quot;html_d9b3cf18607b2badcd27cbf5f5a14005&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c28d61a302cbe74aed13f8761b1ad94d.setContent(html_d9b3cf18607b2badcd27cbf5f5a14005);
#
#
#
#         marker_c0cb72c8c185b7563c1b6819f31d279f.bindPopup(popup_c28d61a302cbe74aed13f8761b1ad94d)
#         ;
#
#
#
#
#             var marker_6f5d9fa730ac91efd7e2a2c9d01df759 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a62117c69d8a2241e64ba18818bbdb34);
#
#
#         var popup_2c7a548070d508d88bb39ada35d9f698 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f8a6758533a3b200164ac0cc832fce1 = $(`&lt;div id=&quot;html_4f8a6758533a3b200164ac0cc832fce1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2c7a548070d508d88bb39ada35d9f698.setContent(html_4f8a6758533a3b200164ac0cc832fce1);
#
#
#
#         marker_6f5d9fa730ac91efd7e2a2c9d01df759.bindPopup(popup_2c7a548070d508d88bb39ada35d9f698)
#         ;
#
#
#
#
#             var marker_0e2e47f0ea88fcf4fcc6a7cc634db0d6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a62117c69d8a2241e64ba18818bbdb34);
#
#
#         var popup_4f7785434104850f2c0b2294c5932978 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_183342add7a0c2526e258128e11344ad = $(`&lt;div id=&quot;html_183342add7a0c2526e258128e11344ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4f7785434104850f2c0b2294c5932978.setContent(html_183342add7a0c2526e258128e11344ad);
#
#
#
#         marker_0e2e47f0ea88fcf4fcc6a7cc634db0d6.bindPopup(popup_4f7785434104850f2c0b2294c5932978)
#         ;
#
#
#
#
#             var marker_73eb8cfd76ef1d01265804f0f9ddb2ef = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a62117c69d8a2241e64ba18818bbdb34);
#
#
#         var popup_66730847872c52448ffaeff9835ab14d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_631568870eaff2f1b3b352f0f726398a = $(`&lt;div id=&quot;html_631568870eaff2f1b3b352f0f726398a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_66730847872c52448ffaeff9835ab14d.setContent(html_631568870eaff2f1b3b352f0f726398a);
#
#
#
#         marker_73eb8cfd76ef1d01265804f0f9ddb2ef.bindPopup(popup_66730847872c52448ffaeff9835ab14d)
#         ;
#
#
#
#
#             var marker_4b768e578a

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad6044e85484881911ea97d41a66b4f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad6044e85484881911ea97d41a66b4f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad6044e85484881911ea97d41a66b4f9 = L.map(
#                 &quot;map_ad6044e85484881911ea97d41a66b4f9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a1a6bf6536441e66b55b09226c65875 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a1a6bf6536441e66b55b09226c65875.addTo(map_ad6044e85484881911ea97d41a66b4f9);
#
#
#             var feature_group_d6d63261787855ec8b36e0c8727ceca2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_58cd6d27b2dc8ff710a5d6919d8ac175 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d6d63261787855ec8b36e0c8727ceca2);
#
#
#         var popup_95f10dcd9943bf52b56526748ca20aa3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25fe495d5c469eaf5300fd67dab737b9 = $(`&lt;div id=&quot;html_25fe495d5c469eaf5300fd67dab737b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_95f10dcd9943bf52b56526748ca20aa3.setContent(html_25fe495d5c469eaf5300fd67dab737b9);
#
#
#
#         marker_58cd6d27b2dc8ff710a5d6919d8ac175.bindPopup(popup_95f10dcd9943bf52b56526748ca20aa3)
#         ;
#
#
#
#
#             var marker_45456045f9738c5e1c77ab566ba2f69c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d6d63261787855ec8b36e0c8727ceca2);
#
#
#         var popup_13e76f9b22f5e2a4252f85bc0dee46eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad03cbab7a3794f23086e9da23bf5105 = $(`&lt;div id=&quot;html_ad03cbab7a3794f23086e9da23bf5105&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_13e76f9b22f5e2a4252f85bc0dee46eb.setContent(html_ad03cbab7a3794f23086e9da23bf5105);
#
#
#
#         marker_45456045f9738c5e1c77ab566ba2f69c.bindPopup(popup_13e76f9b22f5e2a4252f85bc0dee46eb)
#         ;
#
#
#
#
#             var marker_b99c8cad9c9a70942e034ff9539daee3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d6d63261787855ec8b36e0c8727ceca2);
#
#
#         var popup_90c5125d3cef2891b13722875fd45b24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca78dc20484fdeb60b6291ee289bac39 = $(`&lt;div id=&quot;html_ca78dc20484fdeb60b6291ee289bac39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_90c5125d3cef2891b13722875fd45b24.setContent(html_ca78dc20484fdeb60b6291ee289bac39);
#
#
#
#         marker_b99c8cad9c9a70942e034ff9539daee3.bindPopup(popup_90c5125d3cef2891b13722875fd45b24)
#         ;
#
#
#
#
#             var marker_302a309b51133cc038ec1dd35360061a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d6d63261787855ec8b36e0c8727ceca2);
#
#
#         var popup_ce876a1e8869942054ad883eb9baf520 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_252a2651841512a2ef21d11db60d8733 = $(`&lt;div id=&quot;html_252a2651841512a2ef21d11db60d8733&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ce876a1e8869942054ad883eb9baf520.setContent(html_252a2651841512a2ef21d11db60d8733);
#
#
#
#         marker_302a309b51133cc038ec1dd35360061a.bindPopup(popup_ce876a1e8869942054ad883eb9baf520)
#         ;
#
#
#
#
#             var marker_063b1d1bfbbd9c0e6950af119b2e3f5e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d6d63261787855ec8b36e0c8727ceca2);
#
#
#         var popup_5c7629fcb4f62a74c73f48383112ba2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13062b8b782acab4c9b83697ecac4bbe = $(`&lt;div id=&quot;html_13062b8b782acab4c9b83697ecac4bbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_5c7629fcb4f62a74c7

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b96791e48c1ab47836595609c69b4410 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b96791e48c1ab47836595609c69b4410&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b96791e48c1ab47836595609c69b4410 = L.map(
#                 &quot;map_b96791e48c1ab47836595609c69b4410&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_191b31e999dd405967f767b273216d5a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_191b31e999dd405967f767b273216d5a.addTo(map_b96791e48c1ab47836595609c69b4410);
#
#
#             var feature_group_4a88403e9050140a72ec2a0f9587644d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4a88403e9050140a72ec2a0f9587644d.addTo(map_b96791e48c1ab47836595609c69b4410);
#
#
#             var feature_group_sub_group_6e5c6b76b2223e9960c451e6fd81711f = L.featureGroup.subGroup(
#                 feature_group_4a88403e9050140a72ec2a0f9587644d
#             );
#
#
#             var marker_cf0839db3d20ddaab2ce45a3ba9e6c49 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6e5c6b76b2223e9960c451e6fd81711f);
#
#
#         var popup_1477dc9fad61fc86f00504625198f1f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_021fd05657e84701837a9c56dc741bca = $(`&lt;div id=&quot;html_021fd05657e84701837a9c56dc741bca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1477dc9fad61fc86f00504625198f1f6.setContent(html_021fd05657e84701837a9c56dc741bca);
#
#
#
#         marker_cf0839db3d20ddaab2ce45a3ba9e6c49.bindPopup(popup_1477dc9fad61fc86f00504625198f1f6)
#         ;
#
#
#
#
#             var marker_bd08ce920da48842505b348e29e8b5ec = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6e5c6b76b2223e9960c451e6fd81711f);
#
#
#         var popup_50e503af43cb989b0b1e43bcf9b9af78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74651b13aad9d5c0410898fe65ade4aa = $(`&lt;div id=&quot;html_74651b13aad9d5c0410898fe65ade4aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_50e503af43cb989b0b1e43bcf9b9af78.setContent(html_74651b13aad9d5c0410898fe65ade4aa);
#
#
#
#         marker_bd08ce920da48842505b348e29e8b5ec.bindPopup(popup_50e503af43cb989b0b1e43bcf9b9af78)
#         ;
#
#
#
#
#             var marker_991da140ffc06c5ed7dd79ba19a7f7d9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6e5c6b76b2223e9960c451e6fd81711f);
#
#
#         var popup_755329721e19fb67c6b003fdc39faf64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cba887ad0fe872e4edf9bfa21b20a897 = $(`&lt;div id=&quot;html_cba887ad0fe872e4edf9bfa21b20a897&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_755329721e19fb67c6b003fdc39faf64.setContent(html_cba887ad0fe872e4edf9bfa21b20a897);
#
#
#
#         marker_991da140ffc06c5ed7dd79ba19a7f7d9.bindPopup(popup_755329721e19fb67c6b003fdc39faf64)
#         ;
#
#
#
#
#             var marker_e55663d94de655bf8c5b12f35a7d7bef = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6e5c6b76b2223e9960c451e6fd81711f);
#
#
#         var popup_a5c855d56abb5a010b719bd993cdab57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e2b6fa9266cf2e54ca208c4f931bb2d = $(`&lt;div id=&quot;html_8e2b6fa9266cf2e54ca208c4f931bb2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a5c855d56abb5a010b719bd993cdab57.setContent(html_8e2b6fa9266cf2e54ca208c4f931bb2d);
#
#
#
#         marker_e55663d94de655bf8c5b12f35a7d7bef.bindPopup(popup_a5c855d56abb5a010b719bd993cdab57)
#         ;
#
#
#
#
#             var marker_c3b270d498bfd177c9e89273a06462d0 = L.marker(
#                 [45.050399999999996, 3.0504],
