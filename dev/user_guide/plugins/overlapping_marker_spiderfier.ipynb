# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7f33162cb36a6b7cb5fcc6c4cbaa1d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7f33162cb36a6b7cb5fcc6c4cbaa1d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7f33162cb36a6b7cb5fcc6c4cbaa1d7 = L.map(
#                 &quot;map_e7f33162cb36a6b7cb5fcc6c4cbaa1d7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb8f8732cef5508020c272fddf83df7e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb8f8732cef5508020c272fddf83df7e.addTo(map_e7f33162cb36a6b7cb5fcc6c4cbaa1d7);
#
#
#             var marker_bf94ea1a95859c244ea38ffcbcd4add5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e7f33162cb36a6b7cb5fcc6c4cbaa1d7);
#
#
#         var popup_a9cdb4af412470b34fdf1261ae0dfdcc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8884242b8afe96074783adab638981c9 = $(`&lt;div id=&quot;html_8884242b8afe96074783adab638981c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a9cdb4af412470b34fdf1261ae0dfdcc.setContent(html_8884242b8afe96074783adab638981c9);
#
#
#
#         marker_bf94ea1a95859c244ea38ffcbcd4add5.bindPopup(popup_a9cdb4af412470b34fdf1261ae0dfdcc)
#         ;
#
#
#
#
#             var marker_1b2f41fc423e14b183555e85911ba642 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e7f33162cb36a6b7cb5fcc6c4cbaa1d7);
#
#
#         var popup_9b2bd9dbcf91a87de32d01ebb6480b5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7266cd8ee26584ae12792646bd9a7b94 = $(`&lt;div id=&quot;html_7266cd8ee26584ae12792646bd9a7b94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9b2bd9dbcf91a87de32d01ebb6480b5b.setContent(html_7266cd8ee26584ae12792646bd9a7b94);
#
#
#
#         marker_1b2f41fc423e14b183555e85911ba642.bindPopup(popup_9b2bd9dbcf91a87de32d01ebb6480b5b)
#         ;
#
#
#
#
#             var marker_b8e1d65994e5e87861e3e3b0fa0019b7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e7f33162cb36a6b7cb5fcc6c4cbaa1d7);
#
#
#         var popup_eb4dfec5d968d9dbc7a4fe1f3ef4a03f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71a222d56e677763f50a4edd2498f775 = $(`&lt;div id=&quot;html_71a222d56e677763f50a4edd2498f775&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_eb4dfec5d968d9dbc7a4fe1f3ef4a03f.setContent(html_71a222d56e677763f50a4edd2498f775);
#
#
#
#         marker_b8e1d65994e5e87861e3e3b0fa0019b7.bindPopup(popup_eb4dfec5d968d9dbc7a4fe1f3ef4a03f)
#         ;
#
#
#
#
#             var marker_122eb9ed359ca42d3a178b607fa68853 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e7f33162cb36a6b7cb5fcc6c4cbaa1d7);
#
#
#         var popup_8ddcc30e233a69ee72f4832917940e85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_360cbc1c0f18a12df1b8d72981bfb9e9 = $(`&lt;div id=&quot;html_360cbc1c0f18a12df1b8d72981bfb9e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8ddcc30e233a69ee72f4832917940e85.setContent(html_360cbc1c0f18a12df1b8d72981bfb9e9);
#
#
#
#         marker_122eb9ed359ca42d3a178b607fa68853.bindPopup(popup_8ddcc30e233a69ee72f4832917940e85)
#         ;
#
#
#
#
#             var marker_b092728ac26dbdf02b5eef100ad66702 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e7f33162cb36a6b7cb5fcc6c4cbaa1d7);
#
#
#         var popup_a6aa00f65c09b4000202c3c7b15a799f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_146c6324773f232b43d503a6e0d032f8 = $(`&lt;div id=&quot;html_146c6324773f232b43d503a6e0d032f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a6aa00f65c09b4000202c3c7b15a799f.setContent(html_146c6324773f232b43d503a6e0d032f8);
#
#
#
#         marker_b092728ac26dbdf02b5eef100ad66702.bindPopup(popup_a6aa00f65c09b4000202c3c7b15a799f)
#         ;
#
#
#
#
#             var marker_cc283b675a

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cdccdef46763e946d36f873fbbbaffff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cdccdef46763e946d36f873fbbbaffff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cdccdef46763e946d36f873fbbbaffff = L.map(
#                 &quot;map_cdccdef46763e946d36f873fbbbaffff&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c371dcbd1ba0d0c62f25a4b4e874aea8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c371dcbd1ba0d0c62f25a4b4e874aea8.addTo(map_cdccdef46763e946d36f873fbbbaffff);
#
#
#             var feature_group_eab99bc27f06599e0e951af252df4be2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0df06fda544c9c8394137c2daabfdabc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_eab99bc27f06599e0e951af252df4be2);
#
#
#         var popup_e1612f07b6c0ba432e706943575bcf71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4117a516ec870b5ba54fe2f1e174f56c = $(`&lt;div id=&quot;html_4117a516ec870b5ba54fe2f1e174f56c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e1612f07b6c0ba432e706943575bcf71.setContent(html_4117a516ec870b5ba54fe2f1e174f56c);
#
#
#
#         marker_0df06fda544c9c8394137c2daabfdabc.bindPopup(popup_e1612f07b6c0ba432e706943575bcf71)
#         ;
#
#
#
#
#             var marker_8317477a17d38956cae4f0ba1c104dd2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_eab99bc27f06599e0e951af252df4be2);
#
#
#         var popup_1c2ffb4deb91243519e932a0e0e84957 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5de63f8744f53c8ac957df86d63e71f6 = $(`&lt;div id=&quot;html_5de63f8744f53c8ac957df86d63e71f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1c2ffb4deb91243519e932a0e0e84957.setContent(html_5de63f8744f53c8ac957df86d63e71f6);
#
#
#
#         marker_8317477a17d38956cae4f0ba1c104dd2.bindPopup(popup_1c2ffb4deb91243519e932a0e0e84957)
#         ;
#
#
#
#
#             var marker_0edf3d5c5c7933e18627c85a764de503 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_eab99bc27f06599e0e951af252df4be2);
#
#
#         var popup_2e17999252a14f0f77c0e0d9208781a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_baae6e71992a1bed478371ce9fc559b4 = $(`&lt;div id=&quot;html_baae6e71992a1bed478371ce9fc559b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2e17999252a14f0f77c0e0d9208781a1.setContent(html_baae6e71992a1bed478371ce9fc559b4);
#
#
#
#         marker_0edf3d5c5c7933e18627c85a764de503.bindPopup(popup_2e17999252a14f0f77c0e0d9208781a1)
#         ;
#
#
#
#
#             var marker_7766dc411dbd67a94e68aa829a8f827b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_eab99bc27f06599e0e951af252df4be2);
#
#
#         var popup_0fb493183884a8ab76327e13cd08f85f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d9d58f902d6a3e43152c15958bfdadc = $(`&lt;div id=&quot;html_6d9d58f902d6a3e43152c15958bfdadc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0fb493183884a8ab76327e13cd08f85f.setContent(html_6d9d58f902d6a3e43152c15958bfdadc);
#
#
#
#         marker_7766dc411dbd67a94e68aa829a8f827b.bindPopup(popup_0fb493183884a8ab76327e13cd08f85f)
#         ;
#
#
#
#
#             var marker_ab10eef0ae2c812e05ad2de70f3fda60 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_eab99bc27f06599e0e951af252df4be2);
#
#
#         var popup_160eb397b016fda4fedf25b254f130c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddf6141c9e1f9b3eb9e64068a36f9baa = $(`&lt;div id=&quot;html_ddf6141c9e1f9b3eb9e64068a36f9baa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_160eb397b016fda4fe

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ecd9a181e88e1074fe5d004997e7e78a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ecd9a181e88e1074fe5d004997e7e78a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ecd9a181e88e1074fe5d004997e7e78a = L.map(
#                 &quot;map_ecd9a181e88e1074fe5d004997e7e78a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dea39d4fa9c6f0485347c981aee603d1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dea39d4fa9c6f0485347c981aee603d1.addTo(map_ecd9a181e88e1074fe5d004997e7e78a);
#
#
#             var feature_group_decd9aa06a800d1274da34dd3e518e05 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_decd9aa06a800d1274da34dd3e518e05.addTo(map_ecd9a181e88e1074fe5d004997e7e78a);
#
#
#             var feature_group_sub_group_d59789547ac3aa68244e3aeb7f16d0b2 = L.featureGroup.subGroup(
#                 feature_group_decd9aa06a800d1274da34dd3e518e05
#             );
#
#
#             var marker_b5a207988ad240b76a89f969d935d2c8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d59789547ac3aa68244e3aeb7f16d0b2);
#
#
#         var popup_b7b1ead66bbd1583e54a5c92388392bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c39b11c8a4857f4ffcb845f86858153b = $(`&lt;div id=&quot;html_c39b11c8a4857f4ffcb845f86858153b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b7b1ead66bbd1583e54a5c92388392bb.setContent(html_c39b11c8a4857f4ffcb845f86858153b);
#
#
#
#         marker_b5a207988ad240b76a89f969d935d2c8.bindPopup(popup_b7b1ead66bbd1583e54a5c92388392bb)
#         ;
#
#
#
#
#             var marker_bff08407ec2ac1d0b379fb93a1a7b89d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d59789547ac3aa68244e3aeb7f16d0b2);
#
#
#         var popup_752094470a92896332d557125e006aba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3105ff00366ef92bb15588c1acf0b67f = $(`&lt;div id=&quot;html_3105ff00366ef92bb15588c1acf0b67f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_752094470a92896332d557125e006aba.setContent(html_3105ff00366ef92bb15588c1acf0b67f);
#
#
#
#         marker_bff08407ec2ac1d0b379fb93a1a7b89d.bindPopup(popup_752094470a92896332d557125e006aba)
#         ;
#
#
#
#
#             var marker_15d4bf55b8e5fcca70a274849f0ea907 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d59789547ac3aa68244e3aeb7f16d0b2);
#
#
#         var popup_d2199bbadaea2f56123aa772a84f852f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3efd0c70f8ab48db02dcf3223f86a9f = $(`&lt;div id=&quot;html_b3efd0c70f8ab48db02dcf3223f86a9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d2199bbadaea2f56123aa772a84f852f.setContent(html_b3efd0c70f8ab48db02dcf3223f86a9f);
#
#
#
#         marker_15d4bf55b8e5fcca70a274849f0ea907.bindPopup(popup_d2199bbadaea2f56123aa772a84f852f)
#         ;
#
#
#
#
#             var marker_6a4e6d135d671c8797756f9bc84b779d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d59789547ac3aa68244e3aeb7f16d0b2);
#
#
#         var popup_63d6b65b822bbc71a940efa60588143e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf93679e87425c1a2eaa9685f5a04c74 = $(`&lt;div id=&quot;html_bf93679e87425c1a2eaa9685f5a04c74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_63d6b65b822bbc71a940efa60588143e.setContent(html_bf93679e87425c1a2eaa9685f5a04c74);
#
#
#
#         marker_6a4e6d135d671c8797756f9bc84b779d.bindPopup(popup_63d6b65b822bbc71a940efa60588143e)
#         ;
#
#
#
#
#             var marker_7f38ad54f0aa766ec4f24b0c0c2d6538 = L.marker(
#                 [45.050399999999996, 3.0504],
