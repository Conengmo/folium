# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f088131b2dae58bdd39487d0f29e507 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f088131b2dae58bdd39487d0f29e507&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f088131b2dae58bdd39487d0f29e507 = L.map(
#                 &quot;map_4f088131b2dae58bdd39487d0f29e507&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dcd6fab77ad3ec582563258b4e2daa86 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dcd6fab77ad3ec582563258b4e2daa86.addTo(map_4f088131b2dae58bdd39487d0f29e507);
#
#
#             var marker_fccec84e0f41581f66196cf807188040 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4f088131b2dae58bdd39487d0f29e507);
#
#
#         var popup_9295ecccb84f08938bfbdf910a3cc524 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27d5d455ea18a82257c3341aa5c9224a = $(`&lt;div id=&quot;html_27d5d455ea18a82257c3341aa5c9224a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9295ecccb84f08938bfbdf910a3cc524.setContent(html_27d5d455ea18a82257c3341aa5c9224a);
#
#
#
#         marker_fccec84e0f41581f66196cf807188040.bindPopup(popup_9295ecccb84f08938bfbdf910a3cc524)
#         ;
#
#
#
#
#             var marker_b6b59b1d587b77ec4b7e0c021c58f3aa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4f088131b2dae58bdd39487d0f29e507);
#
#
#         var popup_3bd1ba9255e82c3584c4b50a9c1b4a62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_daadf7874d6d5fe2dc71bb91c34fc7f4 = $(`&lt;div id=&quot;html_daadf7874d6d5fe2dc71bb91c34fc7f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3bd1ba9255e82c3584c4b50a9c1b4a62.setContent(html_daadf7874d6d5fe2dc71bb91c34fc7f4);
#
#
#
#         marker_b6b59b1d587b77ec4b7e0c021c58f3aa.bindPopup(popup_3bd1ba9255e82c3584c4b50a9c1b4a62)
#         ;
#
#
#
#
#             var marker_cd32fb116eb9e59cb7ce487b575947f0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4f088131b2dae58bdd39487d0f29e507);
#
#
#         var popup_34779be1ed20935eb37acfe7ac8e3dd0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b16f0adbddb08e62c08be8c2eaa85f11 = $(`&lt;div id=&quot;html_b16f0adbddb08e62c08be8c2eaa85f11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_34779be1ed20935eb37acfe7ac8e3dd0.setContent(html_b16f0adbddb08e62c08be8c2eaa85f11);
#
#
#
#         marker_cd32fb116eb9e59cb7ce487b575947f0.bindPopup(popup_34779be1ed20935eb37acfe7ac8e3dd0)
#         ;
#
#
#
#
#             var marker_329f49683abf82611138003f868a9cb7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4f088131b2dae58bdd39487d0f29e507);
#
#
#         var popup_da24da1a1fbafb5f99d4070dfe691366 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcb0a9a5f88b56c1e7b4626acb244fe0 = $(`&lt;div id=&quot;html_dcb0a9a5f88b56c1e7b4626acb244fe0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_da24da1a1fbafb5f99d4070dfe691366.setContent(html_dcb0a9a5f88b56c1e7b4626acb244fe0);
#
#
#
#         marker_329f49683abf82611138003f868a9cb7.bindPopup(popup_da24da1a1fbafb5f99d4070dfe691366)
#         ;
#
#
#
#
#             var marker_1c2a451d4ed9b994ce296cb04e5c0ace = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4f088131b2dae58bdd39487d0f29e507);
#
#
#         var popup_f7d334abd26d3223ce353ae081d04ef4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35c10608ee6a05821a4e09d81baeb204 = $(`&lt;div id=&quot;html_35c10608ee6a05821a4e09d81baeb204&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f7d334abd26d3223ce353ae081d04ef4.setContent(html_35c10608ee6a05821a4e09d81baeb204);
#
#
#
#         marker_1c2a451d4ed9b994ce296cb04e5c0ace.bindPopup(popup_f7d334abd26d3223ce353ae081d04ef4)
#         ;
#
#
#
#
#             var marker_07652af1ba

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1264f2977576c65a7556ec1eae5562da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1264f2977576c65a7556ec1eae5562da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1264f2977576c65a7556ec1eae5562da = L.map(
#                 &quot;map_1264f2977576c65a7556ec1eae5562da&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67d9242d77090d82d28a9697aaac89ba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_67d9242d77090d82d28a9697aaac89ba.addTo(map_1264f2977576c65a7556ec1eae5562da);
#
#
#             var feature_group_2996cfb3b13f010403d7322d6be7cbe0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b558a606863051aa5e6c11858a0846a2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2996cfb3b13f010403d7322d6be7cbe0);
#
#
#         var popup_dea6067f700c9d325499021504d7fc50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d674b31e515cac5c845e9f3dc3c525f = $(`&lt;div id=&quot;html_3d674b31e515cac5c845e9f3dc3c525f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_dea6067f700c9d325499021504d7fc50.setContent(html_3d674b31e515cac5c845e9f3dc3c525f);
#
#
#
#         marker_b558a606863051aa5e6c11858a0846a2.bindPopup(popup_dea6067f700c9d325499021504d7fc50)
#         ;
#
#
#
#
#             var marker_3b6b2e78c463771093ddb3e170e45fc3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2996cfb3b13f010403d7322d6be7cbe0);
#
#
#         var popup_b1088af4c1766545b7eaa83bfa719ce2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f78b45db58b764803eefd20c5394f76b = $(`&lt;div id=&quot;html_f78b45db58b764803eefd20c5394f76b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b1088af4c1766545b7eaa83bfa719ce2.setContent(html_f78b45db58b764803eefd20c5394f76b);
#
#
#
#         marker_3b6b2e78c463771093ddb3e170e45fc3.bindPopup(popup_b1088af4c1766545b7eaa83bfa719ce2)
#         ;
#
#
#
#
#             var marker_dff25ea412375c75f5ecc54813c8d63e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2996cfb3b13f010403d7322d6be7cbe0);
#
#
#         var popup_74806261d76489f8077fe3ae32d4a812 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13089573e577f4a58fe8f0100b343863 = $(`&lt;div id=&quot;html_13089573e577f4a58fe8f0100b343863&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_74806261d76489f8077fe3ae32d4a812.setContent(html_13089573e577f4a58fe8f0100b343863);
#
#
#
#         marker_dff25ea412375c75f5ecc54813c8d63e.bindPopup(popup_74806261d76489f8077fe3ae32d4a812)
#         ;
#
#
#
#
#             var marker_4c9505146427e9bae69dbe08f7bc2807 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2996cfb3b13f010403d7322d6be7cbe0);
#
#
#         var popup_12f0ff78668a6badad646b9f3e1d5e16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6149364611dff039634acfb886df9326 = $(`&lt;div id=&quot;html_6149364611dff039634acfb886df9326&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_12f0ff78668a6badad646b9f3e1d5e16.setContent(html_6149364611dff039634acfb886df9326);
#
#
#
#         marker_4c9505146427e9bae69dbe08f7bc2807.bindPopup(popup_12f0ff78668a6badad646b9f3e1d5e16)
#         ;
#
#
#
#
#             var marker_837464ded588ee64a5dfa6af7cece23d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2996cfb3b13f010403d7322d6be7cbe0);
#
#
#         var popup_60bf3a5e8c251602c98b2c1bdd6f0c40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4f08bfbb9b3dbb63b04301fa95b1a63 = $(`&lt;div id=&quot;html_c4f08bfbb9b3dbb63b04301fa95b1a63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_60bf3a5e8c251602c9

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b04eb34f092cfdf352f732ff7e980fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b04eb34f092cfdf352f732ff7e980fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b04eb34f092cfdf352f732ff7e980fe = L.map(
#                 &quot;map_0b04eb34f092cfdf352f732ff7e980fe&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca5e4601da09c68b253f2991e9ddf2bb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ca5e4601da09c68b253f2991e9ddf2bb.addTo(map_0b04eb34f092cfdf352f732ff7e980fe);
#
#
#             var feature_group_73906ba1f095732b0759688e20937e7f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_73906ba1f095732b0759688e20937e7f.addTo(map_0b04eb34f092cfdf352f732ff7e980fe);
#
#
#             var feature_group_sub_group_1e3883356694914c27aaa67af30a906f = L.featureGroup.subGroup(
#                 feature_group_73906ba1f095732b0759688e20937e7f
#             );
#
#
#             var marker_498199b3d01776f142f5daf5351a192c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1e3883356694914c27aaa67af30a906f);
#
#
#         var popup_e8a1e1dc79db3584e6dce273a16c5e86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a6bcee5c742dc6b0c96e65014b37f80 = $(`&lt;div id=&quot;html_6a6bcee5c742dc6b0c96e65014b37f80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e8a1e1dc79db3584e6dce273a16c5e86.setContent(html_6a6bcee5c742dc6b0c96e65014b37f80);
#
#
#
#         marker_498199b3d01776f142f5daf5351a192c.bindPopup(popup_e8a1e1dc79db3584e6dce273a16c5e86)
#         ;
#
#
#
#
#             var marker_2e6887a260da06340a59f271a07bcec5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1e3883356694914c27aaa67af30a906f);
#
#
#         var popup_be6cd7f93a0a738d0bde096abe57efd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cdab576ecca49adc6bf16ba9e2e5135d = $(`&lt;div id=&quot;html_cdab576ecca49adc6bf16ba9e2e5135d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_be6cd7f93a0a738d0bde096abe57efd7.setContent(html_cdab576ecca49adc6bf16ba9e2e5135d);
#
#
#
#         marker_2e6887a260da06340a59f271a07bcec5.bindPopup(popup_be6cd7f93a0a738d0bde096abe57efd7)
#         ;
#
#
#
#
#             var marker_62e3fff6dcba80e5ce370a9ff4d636e3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1e3883356694914c27aaa67af30a906f);
#
#
#         var popup_b0e6b00f457e6add2801d443fa088e71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e871aeb95afc80c440fa7c8bca7a6bc = $(`&lt;div id=&quot;html_9e871aeb95afc80c440fa7c8bca7a6bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b0e6b00f457e6add2801d443fa088e71.setContent(html_9e871aeb95afc80c440fa7c8bca7a6bc);
#
#
#
#         marker_62e3fff6dcba80e5ce370a9ff4d636e3.bindPopup(popup_b0e6b00f457e6add2801d443fa088e71)
#         ;
#
#
#
#
#             var marker_951eb52b44b5f0ce0c00ee1f9455dfe8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1e3883356694914c27aaa67af30a906f);
#
#
#         var popup_e38067452a2040b486f325b7e9588153 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf1fc25a4051fcb6c3bd1c591f5c39f1 = $(`&lt;div id=&quot;html_bf1fc25a4051fcb6c3bd1c591f5c39f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e38067452a2040b486f325b7e9588153.setContent(html_bf1fc25a4051fcb6c3bd1c591f5c39f1);
#
#
#
#         marker_951eb52b44b5f0ce0c00ee1f9455dfe8.bindPopup(popup_e38067452a2040b486f325b7e9588153)
#         ;
#
#
#
#
#             var marker_9b3dc20cf5c99a807b4c05b4a0491693 = L.marker(
#                 [45.050399999999996, 3.0504],
