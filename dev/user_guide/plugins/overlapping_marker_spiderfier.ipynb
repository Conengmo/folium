# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_adb9587478bf2bf5ae7aafabc595923f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_adb9587478bf2bf5ae7aafabc595923f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_adb9587478bf2bf5ae7aafabc595923f = L.map(
#                 &quot;map_adb9587478bf2bf5ae7aafabc595923f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae6a506fedf9ee47f19abc5c3f5f2f58 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ae6a506fedf9ee47f19abc5c3f5f2f58.addTo(map_adb9587478bf2bf5ae7aafabc595923f);
#
#
#             var marker_60fa19b75837b537fbd034052d8b280a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_adb9587478bf2bf5ae7aafabc595923f);
#
#
#         var popup_f2d047494883292fd7b561c8e9c018ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ac6783ee4e01e965676533793d564d7 = $(`&lt;div id=&quot;html_9ac6783ee4e01e965676533793d564d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f2d047494883292fd7b561c8e9c018ba.setContent(html_9ac6783ee4e01e965676533793d564d7);
#
#
#
#         marker_60fa19b75837b537fbd034052d8b280a.bindPopup(popup_f2d047494883292fd7b561c8e9c018ba)
#         ;
#
#
#
#
#             var marker_d2ffab189c0ec947597f35dc7fbf5928 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_adb9587478bf2bf5ae7aafabc595923f);
#
#
#         var popup_7435ce00020f4a2cdf3c00c0d97f8b0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_362bbca06188a1c086b3b9cb2b765008 = $(`&lt;div id=&quot;html_362bbca06188a1c086b3b9cb2b765008&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7435ce00020f4a2cdf3c00c0d97f8b0a.setContent(html_362bbca06188a1c086b3b9cb2b765008);
#
#
#
#         marker_d2ffab189c0ec947597f35dc7fbf5928.bindPopup(popup_7435ce00020f4a2cdf3c00c0d97f8b0a)
#         ;
#
#
#
#
#             var marker_e1ca8f3310a15f792036183663ebb4d9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_adb9587478bf2bf5ae7aafabc595923f);
#
#
#         var popup_6d91a48311de43e5dd2bb4a9e27b7101 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80f17dc3afc8719616a8a6e4a0c296db = $(`&lt;div id=&quot;html_80f17dc3afc8719616a8a6e4a0c296db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6d91a48311de43e5dd2bb4a9e27b7101.setContent(html_80f17dc3afc8719616a8a6e4a0c296db);
#
#
#
#         marker_e1ca8f3310a15f792036183663ebb4d9.bindPopup(popup_6d91a48311de43e5dd2bb4a9e27b7101)
#         ;
#
#
#
#
#             var marker_4565877b2794a7520fc943c17ed8cfd0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_adb9587478bf2bf5ae7aafabc595923f);
#
#
#         var popup_e7f39f9f456864b29d9dfd71085d03b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01736d56f48bb412e5dda9a7c91e403c = $(`&lt;div id=&quot;html_01736d56f48bb412e5dda9a7c91e403c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e7f39f9f456864b29d9dfd71085d03b5.setContent(html_01736d56f48bb412e5dda9a7c91e403c);
#
#
#
#         marker_4565877b2794a7520fc943c17ed8cfd0.bindPopup(popup_e7f39f9f456864b29d9dfd71085d03b5)
#         ;
#
#
#
#
#             var marker_6ed8874ab47a1a52910f83744754d31a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_adb9587478bf2bf5ae7aafabc595923f);
#
#
#         var popup_16b5bef224f68e22dfc3ed826d4f192f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16e260418090c8e25fb8ba5d3f42fe5e = $(`&lt;div id=&quot;html_16e260418090c8e25fb8ba5d3f42fe5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_16b5bef224f68e22dfc3ed826d4f192f.setContent(html_16e260418090c8e25fb8ba5d3f42fe5e);
#
#
#
#         marker_6ed8874ab47a1a52910f83744754d31a.bindPopup(popup_16b5bef224f68e22dfc3ed826d4f192f)
#         ;
#
#
#
#
#             var marker_ad2ac0d97b

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d711ccc9fec3ca0a9887b27a1498458 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d711ccc9fec3ca0a9887b27a1498458&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d711ccc9fec3ca0a9887b27a1498458 = L.map(
#                 &quot;map_1d711ccc9fec3ca0a9887b27a1498458&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61c55b1bcfcfaabd29be0e5aed97c7c4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61c55b1bcfcfaabd29be0e5aed97c7c4.addTo(map_1d711ccc9fec3ca0a9887b27a1498458);
#
#
#             var feature_group_8c18eaa640cbcc2d064d7fbb84213dfe = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4af8ca2ee50a5a14e1ec79229fff104e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8c18eaa640cbcc2d064d7fbb84213dfe);
#
#
#         var popup_b14cc3b3a90c4ab00ff7fd0f60c396e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83217f7d84513bcd3d00fedec37ca1f4 = $(`&lt;div id=&quot;html_83217f7d84513bcd3d00fedec37ca1f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b14cc3b3a90c4ab00ff7fd0f60c396e9.setContent(html_83217f7d84513bcd3d00fedec37ca1f4);
#
#
#
#         marker_4af8ca2ee50a5a14e1ec79229fff104e.bindPopup(popup_b14cc3b3a90c4ab00ff7fd0f60c396e9)
#         ;
#
#
#
#
#             var marker_c20e5c48b224b16f04191c82dfc6fff3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8c18eaa640cbcc2d064d7fbb84213dfe);
#
#
#         var popup_18089e7ca1ac4afe668c5a4268585503 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3397bee8ac704a6428d983785140c307 = $(`&lt;div id=&quot;html_3397bee8ac704a6428d983785140c307&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_18089e7ca1ac4afe668c5a4268585503.setContent(html_3397bee8ac704a6428d983785140c307);
#
#
#
#         marker_c20e5c48b224b16f04191c82dfc6fff3.bindPopup(popup_18089e7ca1ac4afe668c5a4268585503)
#         ;
#
#
#
#
#             var marker_570d2718b6619b3de722004a25413779 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8c18eaa640cbcc2d064d7fbb84213dfe);
#
#
#         var popup_541119920a926ca5072a5e561a1fe375 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0a2c3473331efa4809239b447c4b45b = $(`&lt;div id=&quot;html_e0a2c3473331efa4809239b447c4b45b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_541119920a926ca5072a5e561a1fe375.setContent(html_e0a2c3473331efa4809239b447c4b45b);
#
#
#
#         marker_570d2718b6619b3de722004a25413779.bindPopup(popup_541119920a926ca5072a5e561a1fe375)
#         ;
#
#
#
#
#             var marker_a13610b830d40670df8c22731f88ffef = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8c18eaa640cbcc2d064d7fbb84213dfe);
#
#
#         var popup_2b338288505bfd46eb2be52aad3ebbbe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bf5fb31a94c3ec791f369fa0e4b6ece = $(`&lt;div id=&quot;html_5bf5fb31a94c3ec791f369fa0e4b6ece&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2b338288505bfd46eb2be52aad3ebbbe.setContent(html_5bf5fb31a94c3ec791f369fa0e4b6ece);
#
#
#
#         marker_a13610b830d40670df8c22731f88ffef.bindPopup(popup_2b338288505bfd46eb2be52aad3ebbbe)
#         ;
#
#
#
#
#             var marker_9ed423bc4e469d2219244e130e9b2955 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8c18eaa640cbcc2d064d7fbb84213dfe);
#
#
#         var popup_66627bf19a34815e55957b54d230e76c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5f1f943ff2750dbda4d31229aa8a429 = $(`&lt;div id=&quot;html_d5f1f943ff2750dbda4d31229aa8a429&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_66627bf19a34815e55

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_042125c61fad4297c5bfcf85c4926001 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_042125c61fad4297c5bfcf85c4926001&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_042125c61fad4297c5bfcf85c4926001 = L.map(
#                 &quot;map_042125c61fad4297c5bfcf85c4926001&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fbcb19518da78db98b3c70b381bc3ad2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fbcb19518da78db98b3c70b381bc3ad2.addTo(map_042125c61fad4297c5bfcf85c4926001);
#
#
#             var feature_group_471855cac12796f43deee1f49d9ba4fd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_471855cac12796f43deee1f49d9ba4fd.addTo(map_042125c61fad4297c5bfcf85c4926001);
#
#
#             var feature_group_sub_group_86f9696be1926ee940252a25a46ba2b2 = L.featureGroup.subGroup(
#                 feature_group_471855cac12796f43deee1f49d9ba4fd
#             );
#
#
#             var marker_6c21a2329eed3934f58aaf3e92f3b84b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_86f9696be1926ee940252a25a46ba2b2);
#
#
#         var popup_75b510f63c088403ab7472789c309c69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4c792cc20e4dfa5769414d68ffaf9f1 = $(`&lt;div id=&quot;html_a4c792cc20e4dfa5769414d68ffaf9f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_75b510f63c088403ab7472789c309c69.setContent(html_a4c792cc20e4dfa5769414d68ffaf9f1);
#
#
#
#         marker_6c21a2329eed3934f58aaf3e92f3b84b.bindPopup(popup_75b510f63c088403ab7472789c309c69)
#         ;
#
#
#
#
#             var marker_18bad47218fbd3b2a41850c377fc64e4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_86f9696be1926ee940252a25a46ba2b2);
#
#
#         var popup_76d1cf13c5e056976308dee16b317a18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90c954c398e91bafd62db6ceff8ac52b = $(`&lt;div id=&quot;html_90c954c398e91bafd62db6ceff8ac52b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_76d1cf13c5e056976308dee16b317a18.setContent(html_90c954c398e91bafd62db6ceff8ac52b);
#
#
#
#         marker_18bad47218fbd3b2a41850c377fc64e4.bindPopup(popup_76d1cf13c5e056976308dee16b317a18)
#         ;
#
#
#
#
#             var marker_122182e014df959d10e2ca54ba5ef986 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_86f9696be1926ee940252a25a46ba2b2);
#
#
#         var popup_a2df0c53305e219624755f9b4c8b4196 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e880de970c1ddbe2897534d0d63e157 = $(`&lt;div id=&quot;html_2e880de970c1ddbe2897534d0d63e157&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a2df0c53305e219624755f9b4c8b4196.setContent(html_2e880de970c1ddbe2897534d0d63e157);
#
#
#
#         marker_122182e014df959d10e2ca54ba5ef986.bindPopup(popup_a2df0c53305e219624755f9b4c8b4196)
#         ;
#
#
#
#
#             var marker_1ac818f0b9b623ad8193a72564c71836 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_86f9696be1926ee940252a25a46ba2b2);
#
#
#         var popup_5a77ecd99a8a510a8dd82d9a3e0c34ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f5778c5491841eb988735a7099e754e = $(`&lt;div id=&quot;html_8f5778c5491841eb988735a7099e754e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5a77ecd99a8a510a8dd82d9a3e0c34ea.setContent(html_8f5778c5491841eb988735a7099e754e);
#
#
#
#         marker_1ac818f0b9b623ad8193a72564c71836.bindPopup(popup_5a77ecd99a8a510a8dd82d9a3e0c34ea)
#         ;
#
#
#
#
#             var marker_181dd3c7b52089ab359089406efb9add = L.marker(
#                 [45.050399999999996, 3.0504],
