# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f6af827f7aa5e13fbe1f0a4a2b68b838 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f6af827f7aa5e13fbe1f0a4a2b68b838&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f6af827f7aa5e13fbe1f0a4a2b68b838 = L.map(
#                 &quot;map_f6af827f7aa5e13fbe1f0a4a2b68b838&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_468a60428db7a9f141c937f408ceaf52 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_468a60428db7a9f141c937f408ceaf52.addTo(map_f6af827f7aa5e13fbe1f0a4a2b68b838);
#
#             var marker_cluster_e959ae50a39bb98dc9ef67f0f2481f9f = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_f18d3f9a31762af52a59a51c12acdd19 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_e959ae50a39bb98dc9ef67f0f2481f9f);
#
#
#             var icon_d9d1c5289d1b9b621df31386603c1c45 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f18d3f9a31762af52a59a51c12acdd19.setIcon(icon_d9d1c5289d1b9b621df31386603c1c45);
#
#
#         var popup_18d585d2852de7fce88a1b4f40c54588 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b809240e317d25f749672b7d597b0d3f = $(`&lt;div id=&quot;html_b809240e317d25f749672b7d597b0d3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_18d585d2852de7fce88a1b4f40c54588.setContent(html_b809240e317d25f749672b7d597b0d3f);
#
#
#
#         marker_f18d3f9a31762af52a59a51c12acdd19.bindPopup(popup_18d585d2852de7fce88a1b4f40c54588)
#         ;
#
#
#
#
#             var marker_f539d5580277487601c918d0022c5bec = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_e959ae50a39bb98dc9ef67f0f2481f9f);
#
#
#             var icon_921bd2a4cf9061c644ee70f965bd1fd1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f539d5580277487601c918d0022c5bec.setIcon(icon_921bd2a4cf9061c644ee70f965bd1fd1);
#
#
#         var popup_29dcdc4a7adbf91c79b932fec221469e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_710099e9f99ab269ba16542366fa0656 = $(`&lt;div id=&quot;html_710099e9f99ab269ba16542366fa0656&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_29dcdc4a7adbf91c79b932fec221469e.setContent(html_710099e9f99ab269ba16542366fa0656);
#
#
#
#         marker_f539d5580277487601c918d0022c5bec.bindPopup(popup_29dcdc4a7adbf91c79b932fec221469e)
#         ;
#
#
#
#
#             var marker_46820f15c4258330417c33033276a3d4 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_e959ae50a39bb98dc9ef67f0f2481f9f);
#
#
#         var popup_6adfcb5893cfc96b4a96f895c0b6df98 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d140dbadbcf0edeb5390affda87d0ca = $(`&lt;div id=&quot;html_0d140dbadbcf0edeb5390affda87d0ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_6adfcb5893cfc96b4a96f895c0b6df98.setContent(html_0d140dbadbcf0edeb5390affda87d0ca);
#
#
#
#         marker_46820f15c4258330417c33033276a3d4.bindPopup(popup_6adfcb5893cfc96b4a96f895c0b6df98)
#         ;
#
#
#
#
#                 marker_cluster_e959ae50a39bb98dc9ef67f0f2481f9f.addTo(map_f6af827f7aa5e13fbe1f0a4a2b68b838);
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></ifr

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31b1c7139a1381fee567fe5b9615e7c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31b1c7139a1381fee567fe5b9615e7c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31b1c7139a1381fee567fe5b9615e7c4 = L.map(
#                 &quot;map_31b1c7139a1381fee567fe5b9615e7c4&quot;,
#                 {
#                     center: [-2.61, -5.23],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afd0f019a2109ee2a03ec8b6e98343a7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_afd0f019a2109ee2a03ec8b6e98343a7.addTo(map_31b1c7139a1381fee567fe5b9615e7c4);
#
#             var marker_cluster_bb06d290202dfdb0f3cabfec0d86588f = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_bb06d290202dfdb0f3cabfec0d86588f.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_4daf74f3f26418a87161ea18e60f458b = L.marker(
#                 [85.0, -150.0],
#                 {}
#             ).addTo(marker_cluster_bb06d290202dfdb0f3cabfec0d86588f);
#
#
#         var popup_e064657e4a7e13fd51bc15c570a83c73 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eb420e54912844eefce5da2f2d1b0c52 = $(`&lt;div id=&quot;html_eb420e54912844eefce5da2f2d1b0c52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-150&lt;br&gt;lat:85&lt;/div&gt;`)[0];
#                 popup_e064657e4a7e13fd51bc15c570a83c73.setContent(html_eb420e54912844eefce5da2f2d1b0c52);
#
#
#
#         marker_4daf74f3f26418a87161ea18e60f458b.bindPopup(popup_e064657e4a7e13fd51bc15c570a83c73)
#         ;
#
#
#
#
#             var marker_4d9ac1763e3592e2f99f516f1c9073f1 = L.marker(
#                 [-63.0, -116.0],
#                 {}
#             ).addTo(marker_cluster_bb06d290202dfdb0f3cabfec0d86588f);
#
#
#         var popup_cf6c1734c4c3e529158b930d3fdf1498 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e0b33241048e74e76c5333471e93fd48 = $(`&lt;div id=&quot;html_e0b33241048e74e76c5333471e93fd48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-116&lt;br&gt;lat:-63&lt;/div&gt;`)[0];
#                 popup_cf6c1734c4c3e529158b930d3fdf1498.setContent(html_e0b33241048e74e76c5333471e93fd48);
#
#
#
#         marker_4d9ac1763e3592e2f99f516f1c9073f1.bindPopup(popup_cf6c1734c4c3e529158b930d3fdf1498)
#         ;
#
#
#
#
#             var marker_096d6ea886888714a3065ac93750623a = L.marker(
#                 [-48.0, 50.0],
#                 {}
#             ).addTo(marker_cluster_bb06d290202dfdb0f3cabfec0d86588f);
#
#
#         var popup_fd6004690af9dd8dda3a00d5d5a6718b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5733f42a90b52fdbbde42a1ecc37b204 = $(`&lt;div id=&quot;html_5733f42a90b52fdbbde42a1ecc37b204&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:50&lt;br&gt;lat:-48&lt;/div&gt;`)[0];
#                 popup_fd6004690af9dd8dda3a00d5d5a6718b.setContent(html_5733f42a90b52fdbbde42a1ecc37b204);
#
#
#
#         marker_096d6ea886888714a3065ac93750623a.bindPopup(popup_fd6004690af9dd8dda3a00d5d5a6718b)
#         ;
#
#
#
#
#             var marker_5be3da3537b38d85749642479f0bd790 = L.marker(
#                 [-66.0, -19.0],
#                 {}
#             ).addTo(marker_cluster_bb06d290202dfdb0f3cabfec0d86588f);
#
#
#         var popup_68df9668f415191b59f3ea9dce5f7511 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3424cbc1b8fb30f1ecda390ee64e3bfa = $(`&lt;div id=&quot;html_3424cbc1b8fb30f1ecda390ee64e3bfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-19&lt;br&gt;lat:-66&lt;/div&gt;`)[0];
#                 popup_68df9668f415191b59f3ea9dce5f7511.setContent(html_3424cbc1b8fb30f1ecda390ee64e3bfa);
#
#
#
#         marker_5be3da3537b38d85749642

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cd80cbaf39637acbb9c51e9257051fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cd80cbaf39637acbb9c51e9257051fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cd80cbaf39637acbb9c51e9257051fb = L.map(
#                 &quot;map_3cd80cbaf39637acbb9c51e9257051fb&quot;,
#                 {
#                     center: [-2.61, -5.23],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4963a4082d8b91f219ab2ee5c1c169bf = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_4963a4082d8b91f219ab2ee5c1c169bf.addTo(map_3cd80cbaf39637acbb9c51e9257051fb);
#
#             var marker_cluster_d8980a89d0235bfe3c052af38a00cf71 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_640781c38dd9c229c07504fcf79b08cf = L.marker(
#                 [85.0, -150.0],
#                 {}
#             ).addTo(marker_cluster_d8980a89d0235bfe3c052af38a00cf71);
#
#
#         var popup_f2d587a0acf173404b79495324c592d9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6ca3f0a8f091390468d97432719146df = $(`&lt;div id=&quot;html_6ca3f0a8f091390468d97432719146df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-150&lt;br&gt;lat:85&lt;/div&gt;`)[0];
#                 popup_f2d587a0acf173404b79495324c592d9.setContent(html_6ca3f0a8f091390468d97432719146df);
#
#
#
#         marker_640781c38dd9c229c07504fcf79b08cf.bindPopup(popup_f2d587a0acf173404b79495324c592d9)
#         ;
#
#
#
#
#             var marker_2082f25ee5d1dc5e1fa175ab0097749a = L.marker(
#                 [-63.0, -116.0],
#                 {}
#             ).addTo(marker_cluster_d8980a89d0235bfe3c052af38a00cf71);
#
#
#         var popup_c6fe5eb68077ea89c5189e94480f21b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a11cf0d8ec6f09e4e316d33c21c03809 = $(`&lt;div id=&quot;html_a11cf0d8ec6f09e4e316d33c21c03809&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-116&lt;br&gt;lat:-63&lt;/div&gt;`)[0];
#                 popup_c6fe5eb68077ea89c5189e94480f21b0.setContent(html_a11cf0d8ec6f09e4e316d33c21c03809);
#
#
#
#         marker_2082f25ee5d1dc5e1fa175ab0097749a.bindPopup(popup_c6fe5eb68077ea89c5189e94480f21b0)
#         ;
#
#
#
#
#             var marker_336cefa307766f9c9658926a8f648e33 = L.marker(
#                 [-48.0, 50.0],
#                 {}
#             ).addTo(marker_cluster_d8980a89d0235bfe3c052af38a00cf71);
#
#
#         var popup_9d1583258407031bdd23187f0570b84d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a27c99bcd3f649c8f5107864ef946cbc = $(`&lt;div id=&quot;html_a27c99bcd3f649c8f5107864ef946cbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:50&lt;br&gt;lat:-48&lt;/div&gt;`)[0];
#                 popup_9d1583258407031bdd23187f0570b84d.setContent(html_a27c99bcd3f649c8f5107864ef946cbc);
#
#
#
#         marker_336cefa307766f9c9658926a8f648e33.bindPopup(popup_9d1583258407031bdd23187f0570b84d)
#         ;
#
#
#
#
#             var marker_0c774a28e633b1e75d86fa0b303f4bd6 = L.marker(
#                 [-66.0, -19.0],
#                 {}
#             ).addTo(marker_cluster_d8980a89d0235bfe3c052af38a00cf71);
#
#
#         var popup_ae4d08676a2dded794abe0fd162841b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_acedc3ec22f14e8ae03eef5229edce48 = $(`&lt;div id=&quot;html_acedc3ec22f14e8ae03eef5229edce48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-19&lt;br&gt;lat:-66&lt;/div&gt;`)[0];
#                 popup_ae4d08676a2dded794abe0fd162841b1.setContent(html_acedc3ec22f14e8ae03eef5229edce48);
#
#
#
#         marker_0c774a28e633b1e75d86fa0b303f4bd6.bindPopup(popup_ae4d08676a2dded794abe0fd162841b1)
#         ;
#
#
#
#
#             var marker_484af394f67d9119db75f37aee7d4eec = L.marker(
#                 [-42.0, -94.0],
#                 {}
#             ).addTo(marker_cluster_d8980a89d0235bfe3c052af38a00cf71);
#
#
#         var popup_8b32747baab1895f90edd62f575f2

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65e3b5c5d52f6ccdefada26dff861ac5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65e3b5c5d52f6ccdefada26dff861ac5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65e3b5c5d52f6ccdefada26dff861ac5 = L.map(
#                 &quot;map_65e3b5c5d52f6ccdefada26dff861ac5&quot;,
#                 {
#                     center: [-2.61, -5.23],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_