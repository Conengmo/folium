# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b7a574c36bc098d644071f46bce031d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b7a574c36bc098d644071f46bce031d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b7a574c36bc098d644071f46bce031d = L.map(
#                 &quot;map_9b7a574c36bc098d644071f46bce031d&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2afef67ec6d66a1a71b0b886ebbafff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e2afef67ec6d66a1a71b0b886ebbafff.addTo(map_9b7a574c36bc098d644071f46bce031d);
#
#
#             var feature_group_6b1b185a3bac6b5f482398aa8065fbf1 = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_6b1b185a3bac6b5f482398aa8065fbf1.addTo(map_9b7a574c36bc098d644071f46bce031d);
#
#
#             var feature_group_sub_group_24af4def5d24e0ca03c0da5f5bd1f0e3 = L.featureGroup.subGroup(
#                 feature_group_6b1b185a3bac6b5f482398aa8065fbf1
#             );
#
#
#             var marker_41a97699d4e37fd018e8b687c55707c9 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_24af4def5d24e0ca03c0da5f5bd1f0e3);
#
#
#             var marker_5ff11380ea084cbf7758261a5d8ac258 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_24af4def5d24e0ca03c0da5f5bd1f0e3);
#
#
#             feature_group_sub_group_24af4def5d24e0ca03c0da5f5bd1f0e3.addTo(map_9b7a574c36bc098d644071f46bce031d);
#
#
#             var feature_group_sub_group_7daa7059c60afed339f9df6e21a0322f = L.featureGroup.subGroup(
#                 feature_group_6b1b185a3bac6b5f482398aa8065fbf1
#             );
#
#
#             var marker_d49ab002936231ae633e82074972abc0 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_7daa7059c60afed339f9df6e21a0322f);
#
#
#             var marker_d04ec514b310b0abf1403e48ba5309ec = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_7daa7059c60afed339f9df6e21a0322f);
#
#
#             feature_group_sub_group_7daa7059c60afed339f9df6e21a0322f.addTo(map_9b7a574c36bc098d644071f46bce031d);
#
#
#             var layer_control_98febc9b5c2add7a46922d88f5719af1_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_e2afef67ec6d66a1a71b0b886ebbafff,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_6b1b185a3bac6b5f482398aa8065fbf1,
#                     &quot;group1&quot; : feature_group_sub_group_24af4def5d24e0ca03c0da5f5bd1f0e3,
#                     &quot;group2&quot; : feature_group_sub_group_7daa7059c60afed339f9df6e21a0322f,
#                 },
#             };
#             let layer_control_98febc9b5c2add7a46922d88f5719af1 = L.control.layers(
#                 layer_control_98febc9b5c2add7a46922d88f5719af1_layers.base_layers,
#                 layer_control_98febc9b5c2add7a46922d88f5719af1_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_9b7a574c36bc098d644071f46bce031d);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ec89ae27de801c89a3c0e6fd7d79359 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ec89ae27de801c89a3c0e6fd7d79359&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5ec89ae27de801c89a3c0e6fd7d79359 = L.map(
#                 &quot;map_5ec89ae27de801c89a3c0e6fd7d79359&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ed3a4f7fe75f7c496dcc20d12e5de5b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8ed3a4f7fe75f7c496dcc20d12e5de5b.addTo(map_5ec89ae27de801c89a3c0e6fd7d79359);
#
#
#             var marker_cluster_e77f97d652ea16baca5eb6e0345464a3 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_e77f97d652ea16baca5eb6e0345464a3.addTo(map_5ec89ae27de801c89a3c0e6fd7d79359);
#
#
#             var feature_group_sub_group_4dbfafad89f405c555a0b582dfe1b31a = L.featureGroup.subGroup(
#                 marker_cluster_e77f97d652ea16baca5eb6e0345464a3
#             );
#
#
#             var marker_04d22c2ed5cd74da90e19a58f3449e22 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_4dbfafad89f405c555a0b582dfe1b31a);
#
#
#             var marker_e4e0ddecbe45080c0f1390f1dbd539c3 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_4dbfafad89f405c555a0b582dfe1b31a);
#
#
#             feature_group_sub_group_4dbfafad89f405c555a0b582dfe1b31a.addTo(map_5ec89ae27de801c89a3c0e6fd7d79359);
#
#
#             var feature_group_sub_group_4f7ab1e2ebf9c9dbf15575391fbfa1c7 = L.featureGroup.subGroup(
#                 marker_cluster_e77f97d652ea16baca5eb6e0345464a3
#             );
#
#
#             var marker_0ca27a89c3f78e38f00214922f0c0f2a = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_4f7ab1e2ebf9c9dbf15575391fbfa1c7);
#
#
#             var marker_d74eb2cb77cd3b4db7fa905d69907bfa = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_4f7ab1e2ebf9c9dbf15575391fbfa1c7);
#
#
#             feature_group_sub_group_4f7ab1e2ebf9c9dbf15575391fbfa1c7.addTo(map_5ec89ae27de801c89a3c0e6fd7d79359);
#
#
#             var layer_control_1a36676a79aa333d1cba9b67130a7773_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_8ed3a4f7fe75f7c496dcc20d12e5de5b,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_4dbfafad89f405c555a0b582dfe1b31a,
#                     &quot;group2&quot; : feature_group_sub_group_4f7ab1e2ebf9c9dbf15575391fbfa1c7,
#                 },
#             };
#             let layer_control_1a36676a79aa333d1cba9b67130a7773 = L.control.layers(
#                 layer_control_1a36676a79aa333d1cba9b67130a7773_layers.base_layers,
#                 layer_control_1a36676a79aa333d1cba9b67130a7773_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_5ec89ae27de801c89a3c0e6fd7d79359);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
