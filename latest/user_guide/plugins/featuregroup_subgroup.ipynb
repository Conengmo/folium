# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d6f8ce81234ec2f7bc6209bd3a7237e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d6f8ce81234ec2f7bc6209bd3a7237e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d6f8ce81234ec2f7bc6209bd3a7237e = L.map(
#                 &quot;map_5d6f8ce81234ec2f7bc6209bd3a7237e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7167465adf576edb3f47640c506504e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f7167465adf576edb3f47640c506504e.addTo(map_5d6f8ce81234ec2f7bc6209bd3a7237e);
#
#
#             var feature_group_c95b861559adfc91ffc7b587bc7a63a1 = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_c95b861559adfc91ffc7b587bc7a63a1.addTo(map_5d6f8ce81234ec2f7bc6209bd3a7237e);
#
#
#             var feature_group_sub_group_85d47b68c574f19284ab2410d8e3dd62 = L.featureGroup.subGroup(
#                 feature_group_c95b861559adfc91ffc7b587bc7a63a1
#             );
#
#
#             var marker_97c68a2a0c2725a9456af2a6dbfb062b = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_85d47b68c574f19284ab2410d8e3dd62);
#
#
#             var marker_1fe84fcfdc9acf6b094ed7df29322816 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_85d47b68c574f19284ab2410d8e3dd62);
#
#
#             feature_group_sub_group_85d47b68c574f19284ab2410d8e3dd62.addTo(map_5d6f8ce81234ec2f7bc6209bd3a7237e);
#
#
#             var feature_group_sub_group_d5d00dd67636ee8479f1b47cbd4bfa26 = L.featureGroup.subGroup(
#                 feature_group_c95b861559adfc91ffc7b587bc7a63a1
#             );
#
#
#             var marker_7fcbcbb747068bbf3792f8f63c0f0b33 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_d5d00dd67636ee8479f1b47cbd4bfa26);
#
#
#             var marker_ab7db8c9fd4f059933d7d8a23aac8947 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_d5d00dd67636ee8479f1b47cbd4bfa26);
#
#
#             feature_group_sub_group_d5d00dd67636ee8479f1b47cbd4bfa26.addTo(map_5d6f8ce81234ec2f7bc6209bd3a7237e);
#
#
#             var layer_control_8c4fa4b2e6cb72e8e63764aa440f8db2_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_f7167465adf576edb3f47640c506504e,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_c95b861559adfc91ffc7b587bc7a63a1,
#                     &quot;group1&quot; : feature_group_sub_group_85d47b68c574f19284ab2410d8e3dd62,
#                     &quot;group2&quot; : feature_group_sub_group_d5d00dd67636ee8479f1b47cbd4bfa26,
#                 },
#             };
#             let layer_control_8c4fa4b2e6cb72e8e63764aa440f8db2 = L.control.layers(
#                 layer_control_8c4fa4b2e6cb72e8e63764aa440f8db2_layers.base_layers,
#                 layer_control_8c4fa4b2e6cb72e8e63764aa440f8db2_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_5d6f8ce81234ec2f7bc6209bd3a7237e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a7a26fcb736ed6b273403f0e4516931 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a7a26fcb736ed6b273403f0e4516931&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a7a26fcb736ed6b273403f0e4516931 = L.map(
#                 &quot;map_0a7a26fcb736ed6b273403f0e4516931&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_280f8465e12ce50e4068f01fa423eebc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_280f8465e12ce50e4068f01fa423eebc.addTo(map_0a7a26fcb736ed6b273403f0e4516931);
#
#
#             var marker_cluster_d9c8a554630104c9b01d300901c58f8a = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_d9c8a554630104c9b01d300901c58f8a.addTo(map_0a7a26fcb736ed6b273403f0e4516931);
#
#
#             var feature_group_sub_group_5f8d999db5c344c3b729c089cf496cbf = L.featureGroup.subGroup(
#                 marker_cluster_d9c8a554630104c9b01d300901c58f8a
#             );
#
#
#             var marker_0e637ab371ed947d4069117323be010f = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_5f8d999db5c344c3b729c089cf496cbf);
#
#
#             var marker_48fe8438d1f6b1edc4c29460e323d96c = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_5f8d999db5c344c3b729c089cf496cbf);
#
#
#             feature_group_sub_group_5f8d999db5c344c3b729c089cf496cbf.addTo(map_0a7a26fcb736ed6b273403f0e4516931);
#
#
#             var feature_group_sub_group_7c7b36ec813a3dd52c853dd656dddb69 = L.featureGroup.subGroup(
#                 marker_cluster_d9c8a554630104c9b01d300901c58f8a
#             );
#
#
#             var marker_12dad67b343a1f69d4a65f8196a5a9a9 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_7c7b36ec813a3dd52c853dd656dddb69);
#
#
#             var marker_6d332b60d3ef95f30c99e5f393c56b0f = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_7c7b36ec813a3dd52c853dd656dddb69);
#
#
#             feature_group_sub_group_7c7b36ec813a3dd52c853dd656dddb69.addTo(map_0a7a26fcb736ed6b273403f0e4516931);
#
#
#             var layer_control_1f6912c98ce2e3b9a4ea19e1eb481090_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_280f8465e12ce50e4068f01fa423eebc,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_5f8d999db5c344c3b729c089cf496cbf,
#                     &quot;group2&quot; : feature_group_sub_group_7c7b36ec813a3dd52c853dd656dddb69,
#                 },
#             };
#             let layer_control_1f6912c98ce2e3b9a4ea19e1eb481090 = L.control.layers(
#                 layer_control_1f6912c98ce2e3b9a4ea19e1eb481090_layers.base_layers,
#                 layer_control_1f6912c98ce2e3b9a4ea19e1eb481090_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_0a7a26fcb736ed6b273403f0e4516931);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
